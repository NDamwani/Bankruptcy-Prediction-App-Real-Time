# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, DistributedSampler
from torch.nn.parallel import DistributedDataParallel as DDP
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
import datetime

# %%
def log_to_file(message, filename="output.txt"):
    with open(filename, "a") as file:
        file.write(message + "\n")

# %%
# Generator model definition
class Generator(nn.Module):
    print("Inside Generator")
    def __init__(self, latent_dim, input_dim, num_classes):
        super(Generator, self).__init__()
        self.label_embedding = nn.Embedding(num_classes, latent_dim)
        
        self.model = nn.Sequential(
            nn.Linear(latent_dim, 128),
            nn.ReLU(True),
            nn.BatchNorm1d(128, momentum=0.8),
            nn.Linear(128, 256),
            nn.ReLU(True),
            nn.BatchNorm1d(256, momentum=0.8),
            nn.Linear(256, input_dim),
            nn.Tanh()
        )

    def forward(self, noise, labels):
        gen_input = torch.mul(self.label_embedding(labels), noise)
        data = self.model(gen_input)
        return data
# Out:
# Inside Generator

# %%
import torch.nn.functional as F

# %%
class Discriminator(nn.Module):
    print("Inside Discriminator")
    log_to_file("Inside Discriminator")

    def __init__(self, input_dim, num_classes):
        super(Discriminator, self).__init__()
        
        self.model = nn.Sequential(
            nn.Conv1d(1, 16, kernel_size=3, stride=2, padding=1),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout(0.25),
            nn.Conv1d(16, 32, kernel_size=3, stride=2, padding=1),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout(0.25),
            nn.BatchNorm1d(32),  # Use BatchNorm instead of SyncBatchNorm for CPU
            nn.Conv1d(32, 64, kernel_size=3, stride=2, padding=1),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout(0.25),
            nn.BatchNorm1d(64),  # Use BatchNorm instead of SyncBatchNorm for CPU
            nn.Conv1d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout(0.25),
            nn.Flatten()
        )

        final_conv_size = self._get_conv_output(input_dim)
        
        self.validity_output = nn.Linear(final_conv_size, 1)
        self.label_output = nn.Linear(final_conv_size, num_classes)
        self.softmax = nn.Softmax(dim=1)

    def _get_conv_output(self, shape):
        with torch.no_grad():
            dummy_input = torch.zeros(1, 1, shape)
            output = self.model(dummy_input)
            return int(np.prod(output.size()))

    def forward(self, data):
        features = self.model(data)
        validity = torch.sigmoid(self.validity_output(features))
        label = self.softmax(self.label_output(features))
        return validity, label
# Out:
# Inside Discriminator

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
class ACGAN():
    def __init__(self, input_dim, latent_dim, num_classes, rank):
        self.input_dim = input_dim
        self.latent_dim = latent_dim
        self.num_classes = num_classes

        # Initialize lists to store synthetic data and labels
        self.synthetic_data = []
        self.synthetic_labels = []

        self.generator = Generator(latent_dim, input_dim, num_classes)
        self.discriminator = Discriminator(input_dim, num_classes)

        # No GPU, so just use the models as they are
        self.generator = self.generator.to('cpu')
        self.discriminator = self.discriminator.to('cpu')

        self.adversarial_loss = nn.BCELoss()
        self.classifier_loss = nn.CrossEntropyLoss()

        self.optimizer_G = optim.Adam(self.generator.parameters(), lr=0.0002, betas=(0.5, 0.999))
        self.optimizer_D = optim.Adam(self.discriminator.parameters(), lr=0.0002, betas=(0.5, 0.999))

    def train(self, X_train, y_train, epochs, batch_size, sample_interval, validation_data, rank, minority_samples=2000):
        print("Inside Train")
        log_to_file("Starting Train...")
        torch.autograd.set_detect_anomaly(True)

        X_train = X_train[:, np.newaxis, :]  # Add channel dimension
        X_val, y_val = validation_data
        X_val = X_val[:, np.newaxis, :]
        print("Inside Train")
        train_dataset = TensorDataset(torch.tensor(X_train).float(), torch.tensor(y_train).long())
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

        val_dataset = TensorDataset(torch.tensor(X_val).float(), torch.tensor(y_val).long())
        val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
        print("Inside Train")
        for epoch in range(epochs):
            train_g_loss, train_d_loss = 0, 0
            train_correct, train_total = 0, 0
            self.generator.train()
            self.discriminator.train()

            for i, (data, labels) in enumerate(train_loader):
                data = data.to('cpu')
                labels = labels.to('cpu')
                batch_size = data.size(0)
                valid = torch.ones(batch_size, 1, device='cpu')
                fake = torch.zeros(batch_size, 1, device='cpu')

                real_data = data

                # Initialize g_loss and gen_data
                g_loss = torch.tensor(0.0, device='cpu')
                gen_data = None

                # Train Generator for Minority Class
                if torch.sum(labels == 1) > 0:
                    self.optimizer_G.zero_grad()

                    z = torch.randn(minority_samples, self.latent_dim, device='cpu')
                    gen_labels = torch.ones(minority_samples, device='cpu').long()

                    gen_data = self.generator(z, gen_labels)
                    gen_data = gen_data.unsqueeze(1)  # Shape: [minority_samples, 1, num_features]

                    self.synthetic_data.append(gen_data.detach().cpu().numpy())
                    self.synthetic_labels.append(gen_labels.detach().cpu().numpy())

                    # Adjust the valid tensor size to match the generated data size
                    valid_fake = torch.ones(gen_data.size(0), 1, device='cpu')

                    validity, pred_label = self.discriminator(gen_data)
                    g_loss = self.adversarial_loss(validity, valid_fake) + \
                             self.classifier_loss(pred_label, gen_labels)
                    g_loss.backward()
                    self.optimizer_G.step()

                # Train Discriminator
                self.optimizer_D.zero_grad()

                validity_real, label_real = self.discriminator(real_data)
                valid = torch.ones(validity_real.size(0), 1, device='cpu')  # Adjust the size of 'valid' to match 'validity_real'
                d_real_loss = self.adversarial_loss(validity_real, valid) + self.classifier_loss(label_real, labels)

                d_loss = d_real_loss  # Start with real data loss

                # If gen_data was generated, include it in the discriminator loss
                if gen_data is not None:
                    validity_fake, label_fake = self.discriminator(gen_data.detach())
                    fake_fake = torch.zeros(validity_fake.size(0), 1, device='cpu')  # Adjust the size of 'fake_fake' to match 'validity_fake'
                    d_fake_loss = self.adversarial_loss(validity_fake, fake_fake) + \
                                 self.classifier_loss(label_fake, gen_labels)
                    d_loss = (d_real_loss + d_fake_loss) / 2

                d_loss.backward()
                self.optimizer_D.step()

                train_d_loss += d_loss.item()
                train_g_loss += g_loss.item()

                _, predicted_labels = torch.max(label_real, 1)
                train_total += labels.size(0)
                train_correct += (predicted_labels == labels).sum().item()

            train_d_loss /= len(train_loader)
            train_g_loss /= len(train_loader)
            train_accuracy = 100. * train_correct / train_total


            val_correct, val_total, val_d_loss = 0, 0, 0
            self.generator.eval()
            self.discriminator.eval()

            with torch.no_grad():
                for val_data, val_labels in val_loader:
                    val_data = val_data.to('cpu')
                    val_labels = val_labels.to('cpu')

                    validity_real, label_real = self.discriminator(val_data)
                    valid = torch.ones(validity_real.size(0), 1, device='cpu')  # Adjust the size of 'valid' to match 'validity_real'
                    d_real_loss = self.adversarial_loss(validity_real, valid) + \
                                 self.classifier_loss(label_real, val_labels)
                    val_d_loss += d_real_loss.item()

                    _, predicted_labels = torch.max(label_real, 1)
                    val_total += val_labels.size(0)
                    val_correct += (predicted_labels == val_labels).sum().item()

            val_d_loss /= len(val_loader)
            val_accuracy = 100. * val_correct / val_total

            print(f"Rank {rank} | Epoch {epoch+1}/{epochs} | "
                  f"Train Loss: D={train_d_loss:.4f}, G={train_g_loss:.4f} | "
                  f"Train Accuracy: {train_accuracy:.2f}% | "
                  f"Val Loss: D={val_d_loss:.4f} | Val Accuracy: {val_accuracy:.2f}%")
            
            # log_to_file(f"Rank {rank} | Epoch {epoch+1}/{epochs} | "
            #         f"Train Loss: D={train_d_loss:.4f}, G={train_g_loss:.4f} | "
            #         f"Train Accuracy: {train_accuracy:.2f}% | "
            #         f"Val Loss: D={val_d_loss:.4f} | Val Accuracy: {val_accuracy:.2f}%")


    def test(self, X_test, y_test, batch_size, rank):
        print("Inside Test")
        log_to_file("Inside Test...")
        X_test = X_test[:, np.newaxis, :]  # Add channel dimension
        test_dataset = TensorDataset(torch.tensor(X_test).float(), torch.tensor(y_test).long())
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

        test_correct, test_total = 0, 0
        test_d_loss = 0

        self.generator.eval()
        self.discriminator.eval()

        all_labels = []
        all_predictions = []

        with torch.no_grad():
            for test_data, test_labels in test_loader:
                test_data = test_data.to('cpu')
                test_labels = test_labels.to('cpu')

                validity_real, label_real = self.discriminator(test_data)
                valid = torch.ones(validity_real.size(0), 1, device='cpu')  # Adjust the size of 'valid' to match 'validity_real'
                d_real_loss = self.adversarial_loss(validity_real, valid) + self.classifier_loss(label_real, test_labels)

                test_d_loss += d_real_loss.item()

                _, predicted_labels = torch.max(label_real, 1)
                test_total += test_labels.size(0)
                test_correct += (predicted_labels == test_labels).sum().item()

                all_labels.append(test_labels.numpy())
                all_predictions.append(predicted_labels.numpy())

        test_d_loss /= len(test_loader)
        test_accuracy = 100. * test_correct / test_total

        # Flatten the lists of labels and predictions
        all_labels = np.concatenate(all_labels)
        all_predictions = np.concatenate(all_predictions)

        # Calculate Precision, Recall, and F1-Score for the minority class (Bankrupt, class 1)
        precision = precision_score(all_labels, all_predictions, pos_label=1)
        recall = recall_score(all_labels, all_predictions, pos_label=1)
        f1 = f1_score(all_labels, all_predictions, pos_label=1)

        # log_to_file(f"Rank {rank} | Epoch {epoch+1}/{epochs} | "
        #             f"Train Loss: D={train_d_loss:.4f}, G={train_g_loss:.4f} | "
        #             f"Train Accuracy: {train_accuracy:.2f}% | "
        #             f"Val Loss: D={val_d_loss:.4f} | Val Accuracy: {val_accuracy:.2f}%")

# %%
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import StratifiedShuffleSplit

# %%
def main_worker(rank, world_size, data_path):
    print("Inside Main Worker")
    log_to_file("Inside Main worker...")
    # Load and preprocess the dataset
    df = pd.read_excel(data_path)

    # Remove the first two non-numeric columns
    df = df.iloc[:, 2:]  # Assuming the first two columns are non-numeric and need to be removed

    # Ensure all remaining columns are numeric, coerce non-numeric data to NaN
    df = df.apply(pd.to_numeric, errors='coerce')

    # Handle missing values by filling NaN with the mean of each column
    df.fillna(df.mean(), inplace=True)

    X = df.drop(columns=['BankRupt']).values
    y = df['BankRupt'].values

    # Normalize data
    scaler = StandardScaler()
    X = scaler.fit_transform(X)
    print("Scaling Complete")

    # Separate the minority and majority classes
    X_minority = X[y == 1]
    X_majority = X[y == 0]
    y_minority = y[y == 1]
    y_majority = y[y == 0]

    # Split the minority class first into 60:20:20
    X_train_min, X_temp_min, y_train_min, y_temp_min = train_test_split(X_minority, y_minority, test_size=0.4, random_state=42)
    X_val_min, X_test_min, y_val_min, y_test_min = train_test_split(X_temp_min, y_temp_min, test_size=0.5, random_state=42)
    
    # Now split the majority class
    X_train_maj, X_temp_maj, y_train_maj, y_temp_maj = train_test_split(X_majority, y_majority, test_size=0.4, random_state=42)
    X_val_maj, X_test_maj, y_val_maj, y_test_maj = train_test_split(X_temp_maj, y_temp_maj, test_size=0.5, random_state=42)
    print("Splitting Complete")
    # Combine the splits back together
    X_train = np.concatenate([X_train_min, X_train_maj])
    X_val = np.concatenate([X_val_min, X_val_maj])
    X_test = np.concatenate([X_test_min, X_test_maj])
    y_train = np.concatenate([y_train_min, y_train_maj])
    y_val = np.concatenate([y_val_min, y_val_maj])
    y_test = np.concatenate([y_test_min, y_test_maj])

    # Parameters
    input_dim = X.shape[1]  # Number of features in your dataset
    latent_dim = 100
    num_classes = 2  # Binary classification (0: Not Bankrupt, 1: Bankrupt)

    # Initialize ACGAN
    acgan = ACGAN(input_dim=input_dim, latent_dim=latent_dim, num_classes=num_classes, rank=rank)
    print("ACGAN initialized")
    # Train the model with control over the number of synthetic samples for the minority class
    acgan.train(X_train, y_train, epochs=1000, batch_size=16, sample_interval=200, validation_data=(X_val, y_val), rank=rank, minority_samples=10)
    print("Training Complete")


    # Combine synthetic data with original data
    synthetic_data = np.concatenate(acgan.synthetic_data, axis=0).squeeze()  # Remove extra channel dimension
    synthetic_labels = np.concatenate(acgan.synthetic_labels, axis=0)
    
    # Original data as DataFrames
    original_data = np.concatenate([X, y.reshape(-1, 1)], axis=1)
    original_df = pd.DataFrame(original_data, columns=df.columns)

    # Synthetic data as DataFrame
    synthetic_df = pd.DataFrame(np.concatenate([synthetic_data, synthetic_labels.reshape(-1, 1)], axis=1), columns=df.columns)

    # Combine original and synthetic data
    combined_df = pd.concat([original_df, synthetic_df], ignore_index=True)

    # Save combined dataset to an Excel file
    combined_df.to_csv("CombinedDataset_with_SyntheticData.csv", index=False)
    print("Final dataset with synthetic data saved as CombinedDataset_with_SyntheticData.csv")




    # Test the model
    acgan.test(X_test, y_test, batch_size=64, rank=rank)
    print("Testing Complete")

# %%
if __name__ == "__main__":
    main_worker(rank=0, world_size=1, data_path='CompletedDataset.xlsx')
# Out:
# Inside Main Worker
# Scaling Complete
# Splitting Complete
# ACGAN initialized
# Inside Train
# Inside Train
# Inside Train
# Rank 0 | Epoch 1/1000 | Train Loss: D=0.6082, G=0.4820 | Train Accuracy: 97.40% | Val Loss: D=0.4437 | Val Accuracy: 97.77%
# Rank 0 | Epoch 2/1000 | Train Loss: D=0.3659, G=0.9990 | Train Accuracy: 97.54% | Val Loss: D=0.8979 | Val Accuracy: 96.23%
# Rank 0 | Epoch 3/1000 | Train Loss: D=0.3407, G=1.3505 | Train Accuracy: 97.94% | Val Loss: D=0.3461 | Val Accuracy: 97.73%
# Rank 0 | Epoch 4/1000 | Train Loss: D=0.3351, G=1.6022 | Train Accuracy: 98.04% | Val Loss: D=0.3679 | Val Accuracy: 97.46%
# Rank 0 | Epoch 5/1000 | Train Loss: D=0.3361, G=1.7717 | Train Accuracy: 98.03% | Val Loss: D=0.3600 | Val Accuracy: 97.64%
# Rank 0 | Epoch 6/1000 | Train Loss: D=0.3397, G=1.7423 | Train Accuracy: 98.02% | Val Loss: D=0.3451 | Val Accuracy: 97.83%
# Rank 0 | Epoch 7/1000 | Train Loss: D=0.3474, G=1.6998 | Train Accuracy: 97.87% | Val Loss: D=0.4187 | Val Accuracy: 97.97%
# Rank 0 | Epoch 8/1000 | Train Loss: D=0.3537, G=1.6823 | Train Accuracy: 97.77% | Val Loss: D=0.5701 | Val Accuracy: 96.81%
# Rank 0 | Epoch 9/1000 | Train Loss: D=0.3618, G=1.5526 | Train Accuracy: 97.69% | Val Loss: D=0.6732 | Val Accuracy: 97.50%
# Rank 0 | Epoch 10/1000 | Train Loss: D=0.3699, G=1.5331 | Train Accuracy: 97.64% | Val Loss: D=2.1155 | Val Accuracy: 10.37%
# Rank 0 | Epoch 11/1000 | Train Loss: D=0.3760, G=1.3963 | Train Accuracy: 97.45% | Val Loss: D=1.1680 | Val Accuracy: 89.00%
# Rank 0 | Epoch 12/1000 | Train Loss: D=0.3646, G=1.3872 | Train Accuracy: 97.67% | Val Loss: D=0.5416 | Val Accuracy: 97.70%
# Rank 0 | Epoch 13/1000 | Train Loss: D=0.3704, G=1.4455 | Train Accuracy: 97.54% | Val Loss: D=1.4738 | Val Accuracy: 30.14%
# Rank 0 | Epoch 14/1000 | Train Loss: D=0.3783, G=1.4373 | Train Accuracy: 97.61% | Val Loss: D=1.4825 | Val Accuracy: 65.87%
# Rank 0 | Epoch 15/1000 | Train Loss: D=0.3818, G=1.3300 | Train Accuracy: 97.44% | Val Loss: D=0.9031 | Val Accuracy: 96.93%
# Rank 0 | Epoch 16/1000 | Train Loss: D=0.3705, G=1.4343 | Train Accuracy: 97.60% | Val Loss: D=1.1774 | Val Accuracy: 96.42%
# Rank 0 | Epoch 17/1000 | Train Loss: D=0.3711, G=1.4672 | Train Accuracy: 97.61% | Val Loss: D=0.5317 | Val Accuracy: 97.86%
# Rank 0 | Epoch 18/1000 | Train Loss: D=0.3693, G=1.4129 | Train Accuracy: 97.57% | Val Loss: D=3.2123 | Val Accuracy: 5.23%
# Rank 0 | Epoch 19/1000 | Train Loss: D=0.3737, G=1.5067 | Train Accuracy: 97.50% | Val Loss: D=2.8330 | Val Accuracy: 10.55%
# Rank 0 | Epoch 20/1000 | Train Loss: D=0.3696, G=1.4682 | Train Accuracy: 97.48% | Val Loss: D=0.4226 | Val Accuracy: 98.09%
# Rank 0 | Epoch 21/1000 | Train Loss: D=0.3702, G=1.4815 | Train Accuracy: 97.60% | Val Loss: D=0.9856 | Val Accuracy: 89.48%
# Rank 0 | Epoch 22/1000 | Train Loss: D=0.3786, G=1.4794 | Train Accuracy: 97.47% | Val Loss: D=0.8059 | Val Accuracy: 96.48%
# Rank 0 | Epoch 23/1000 | Train Loss: D=0.3726, G=1.5517 | Train Accuracy: 97.55% | Val Loss: D=0.5593 | Val Accuracy: 97.43%
# Rank 0 | Epoch 24/1000 | Train Loss: D=0.3874, G=1.5204 | Train Accuracy: 97.42% | Val Loss: D=0.5031 | Val Accuracy: 97.80%
# Rank 0 | Epoch 25/1000 | Train Loss: D=0.3861, G=1.3829 | Train Accuracy: 97.29% | Val Loss: D=0.3841 | Val Accuracy: 98.18%
# Rank 0 | Epoch 26/1000 | Train Loss: D=0.3905, G=1.3933 | Train Accuracy: 97.27% | Val Loss: D=0.7927 | Val Accuracy: 97.58%
# Rank 0 | Epoch 27/1000 | Train Loss: D=0.3737, G=1.4325 | Train Accuracy: 97.66% | Val Loss: D=0.4874 | Val Accuracy: 97.42%
# Rank 0 | Epoch 28/1000 | Train Loss: D=0.3695, G=1.4077 | Train Accuracy: 97.55% | Val Loss: D=0.8336 | Val Accuracy: 97.07%
# Rank 0 | Epoch 29/1000 | Train Loss: D=0.3813, G=1.4045 | Train Accuracy: 97.42% | Val Loss: D=0.5937 | Val Accuracy: 97.88%
# Rank 0 | Epoch 30/1000 | Train Loss: D=0.3652, G=1.5407 | Train Accuracy: 97.64% | Val Loss: D=0.8518 | Val Accuracy: 96.34%
# Rank 0 | Epoch 31/1000 | Train Loss: D=0.3812, G=1.4846 | Train Accuracy: 97.37% | Val Loss: D=0.4875 | Val Accuracy: 97.67%
# Rank 0 | Epoch 32/1000 | Train Loss: D=0.3607, G=1.5827 | Train Accuracy: 97.58% | Val Loss: D=0.6263 | Val Accuracy: 96.64%
# Rank 0 | Epoch 33/1000 | Train Loss: D=0.3690, G=1.4686 | Train Accuracy: 97.51% | Val Loss: D=0.5244 | Val Accuracy: 96.17%
# Rank 0 | Epoch 34/1000 | Train Loss: D=0.3745, G=1.6385 | Train Accuracy: 97.53% | Val Loss: D=0.7565 | Val Accuracy: 96.56%
# Rank 0 | Epoch 35/1000 | Train Loss: D=0.3745, G=1.4086 | Train Accuracy: 97.53% | Val Loss: D=0.4334 | Val Accuracy: 97.96%
# Rank 0 | Epoch 36/1000 | Train Loss: D=0.3881, G=1.4344 | Train Accuracy: 97.28% | Val Loss: D=0.4472 | Val Accuracy: 98.10%
# Rank 0 | Epoch 37/1000 | Train Loss: D=0.3729, G=1.4703 | Train Accuracy: 97.61% | Val Loss: D=0.3918 | Val Accuracy: 98.11%
# Rank 0 | Epoch 38/1000 | Train Loss: D=0.3906, G=1.4452 | Train Accuracy: 97.20% | Val Loss: D=0.4329 | Val Accuracy: 98.09%
# Rank 0 | Epoch 39/1000 | Train Loss: D=0.3758, G=1.4939 | Train Accuracy: 97.44% | Val Loss: D=0.3973 | Val Accuracy: 98.02%
# Rank 0 | Epoch 40/1000 | Train Loss: D=0.3911, G=1.3560 | Train Accuracy: 97.24% | Val Loss: D=0.3736 | Val Accuracy: 98.16%
# Rank 0 | Epoch 41/1000 | Train Loss: D=0.4022, G=1.2424 | Train Accuracy: 97.27% | Val Loss: D=0.3669 | Val Accuracy: 98.22%
# Rank 0 | Epoch 42/1000 | Train Loss: D=0.3903, G=1.2491 | Train Accuracy: 97.10% | Val Loss: D=0.4033 | Val Accuracy: 97.93%
# Rank 0 | Epoch 43/1000 | Train Loss: D=0.4057, G=1.2162 | Train Accuracy: 97.17% | Val Loss: D=0.6027 | Val Accuracy: 97.97%
# Rank 0 | Epoch 44/1000 | Train Loss: D=0.4020, G=1.1870 | Train Accuracy: 97.18% | Val Loss: D=0.5598 | Val Accuracy: 98.00%
# Rank 0 | Epoch 45/1000 | Train Loss: D=0.4008, G=1.1624 | Train Accuracy: 96.95% | Val Loss: D=0.3445 | Val Accuracy: 98.19%
# Rank 0 | Epoch 46/1000 | Train Loss: D=0.3901, G=1.2259 | Train Accuracy: 97.18% | Val Loss: D=0.4054 | Val Accuracy: 98.24%
# Rank 0 | Epoch 47/1000 | Train Loss: D=0.3914, G=1.3814 | Train Accuracy: 97.32% | Val Loss: D=0.3992 | Val Accuracy: 98.18%
# Rank 0 | Epoch 48/1000 | Train Loss: D=0.3971, G=1.2761 | Train Accuracy: 97.16% | Val Loss: D=0.3506 | Val Accuracy: 98.17%
# Rank 0 | Epoch 49/1000 | Train Loss: D=0.3861, G=1.3989 | Train Accuracy: 97.29% | Val Loss: D=0.4115 | Val Accuracy: 98.10%
# Rank 0 | Epoch 50/1000 | Train Loss: D=0.4123, G=1.3055 | Train Accuracy: 96.97% | Val Loss: D=0.8478 | Val Accuracy: 90.58%
# Rank 0 | Epoch 51/1000 | Train Loss: D=0.4206, G=1.0735 | Train Accuracy: 97.03% | Val Loss: D=0.3457 | Val Accuracy: 98.22%
# Rank 0 | Epoch 52/1000 | Train Loss: D=0.3857, G=1.3316 | Train Accuracy: 97.32% | Val Loss: D=0.3485 | Val Accuracy: 98.24%
# Rank 0 | Epoch 53/1000 | Train Loss: D=0.3998, G=1.3011 | Train Accuracy: 97.16% | Val Loss: D=0.3649 | Val Accuracy: 98.13%
# Rank 0 | Epoch 54/1000 | Train Loss: D=0.3931, G=1.3274 | Train Accuracy: 97.21% | Val Loss: D=0.3928 | Val Accuracy: 98.16%
# Rank 0 | Epoch 55/1000 | Train Loss: D=0.4032, G=1.2560 | Train Accuracy: 96.98% | Val Loss: D=0.4023 | Val Accuracy: 98.21%
# Rank 0 | Epoch 56/1000 | Train Loss: D=0.3995, G=1.1532 | Train Accuracy: 97.08% | Val Loss: D=0.4551 | Val Accuracy: 97.57%
# Rank 0 | Epoch 57/1000 | Train Loss: D=0.3966, G=1.2750 | Train Accuracy: 97.01% | Val Loss: D=0.3695 | Val Accuracy: 98.11%
# Rank 0 | Epoch 58/1000 | Train Loss: D=0.3754, G=1.4278 | Train Accuracy: 97.36% | Val Loss: D=0.3652 | Val Accuracy: 98.13%
# Rank 0 | Epoch 59/1000 | Train Loss: D=0.3855, G=1.3574 | Train Accuracy: 97.11% | Val Loss: D=0.3698 | Val Accuracy: 98.14%
# Rank 0 | Epoch 60/1000 | Train Loss: D=0.3909, G=1.3195 | Train Accuracy: 97.26% | Val Loss: D=0.3754 | Val Accuracy: 98.17%
# Rank 0 | Epoch 61/1000 | Train Loss: D=0.4125, G=1.3176 | Train Accuracy: 97.02% | Val Loss: D=0.3731 | Val Accuracy: 98.22%
# Rank 0 | Epoch 62/1000 | Train Loss: D=0.4098, G=1.2553 | Train Accuracy: 97.02% | Val Loss: D=0.3963 | Val Accuracy: 98.08%
# Rank 0 | Epoch 63/1000 | Train Loss: D=0.4052, G=1.1632 | Train Accuracy: 96.85% | Val Loss: D=0.3544 | Val Accuracy: 98.23%
# Rank 0 | Epoch 64/1000 | Train Loss: D=0.4023, G=1.1924 | Train Accuracy: 97.15% | Val Loss: D=0.3610 | Val Accuracy: 98.16%
# Rank 0 | Epoch 65/1000 | Train Loss: D=0.4230, G=1.1037 | Train Accuracy: 96.61% | Val Loss: D=0.3453 | Val Accuracy: 98.21%
# Rank 0 | Epoch 66/1000 | Train Loss: D=0.4121, G=1.1412 | Train Accuracy: 97.03% | Val Loss: D=0.3616 | Val Accuracy: 98.20%
# Rank 0 | Epoch 67/1000 | Train Loss: D=0.4214, G=1.0183 | Train Accuracy: 96.80% | Val Loss: D=0.3382 | Val Accuracy: 98.19%
# Rank 0 | Epoch 68/1000 | Train Loss: D=0.4353, G=1.1320 | Train Accuracy: 96.63% | Val Loss: D=0.3622 | Val Accuracy: 98.18%
# Rank 0 | Epoch 69/1000 | Train Loss: D=0.4116, G=1.2223 | Train Accuracy: 97.06% | Val Loss: D=0.3431 | Val Accuracy: 98.20%
# Rank 0 | Epoch 70/1000 | Train Loss: D=0.4445, G=1.0262 | Train Accuracy: 96.42% | Val Loss: D=0.3400 | Val Accuracy: 98.22%
# Rank 0 | Epoch 71/1000 | Train Loss: D=0.3964, G=1.1870 | Train Accuracy: 97.15% | Val Loss: D=0.3544 | Val Accuracy: 98.23%
# Rank 0 | Epoch 72/1000 | Train Loss: D=0.4106, G=1.2037 | Train Accuracy: 96.70% | Val Loss: D=0.3450 | Val Accuracy: 98.20%
# Rank 0 | Epoch 73/1000 | Train Loss: D=0.4460, G=1.0776 | Train Accuracy: 96.15% | Val Loss: D=0.3968 | Val Accuracy: 98.17%
# Rank 0 | Epoch 74/1000 | Train Loss: D=0.4264, G=1.1252 | Train Accuracy: 96.60% | Val Loss: D=0.3492 | Val Accuracy: 98.20%
# Rank 0 | Epoch 75/1000 | Train Loss: D=0.4019, G=1.2849 | Train Accuracy: 96.96% | Val Loss: D=0.3459 | Val Accuracy: 98.22%
# Rank 0 | Epoch 76/1000 | Train Loss: D=0.4084, G=1.2392 | Train Accuracy: 96.90% | Val Loss: D=0.3796 | Val Accuracy: 98.12%
# Rank 0 | Epoch 77/1000 | Train Loss: D=0.4440, G=1.0330 | Train Accuracy: 96.25% | Val Loss: D=0.3645 | Val Accuracy: 98.08%
# Rank 0 | Epoch 78/1000 | Train Loss: D=0.4600, G=0.8507 | Train Accuracy: 96.02% | Val Loss: D=0.3339 | Val Accuracy: 98.23%
# Rank 0 | Epoch 79/1000 | Train Loss: D=0.4055, G=1.0902 | Train Accuracy: 97.03% | Val Loss: D=0.3757 | Val Accuracy: 98.22%
# Rank 0 | Epoch 80/1000 | Train Loss: D=0.3994, G=1.2596 | Train Accuracy: 97.19% | Val Loss: D=0.3922 | Val Accuracy: 98.19%
# Rank 0 | Epoch 81/1000 | Train Loss: D=0.4244, G=1.1241 | Train Accuracy: 96.75% | Val Loss: D=0.3902 | Val Accuracy: 98.14%
# Rank 0 | Epoch 82/1000 | Train Loss: D=0.4250, G=1.1200 | Train Accuracy: 96.62% | Val Loss: D=0.4453 | Val Accuracy: 98.13%
# Rank 0 | Epoch 83/1000 | Train Loss: D=0.4561, G=0.9467 | Train Accuracy: 96.42% | Val Loss: D=0.3512 | Val Accuracy: 98.19%
# Rank 0 | Epoch 84/1000 | Train Loss: D=0.4462, G=0.9846 | Train Accuracy: 96.27% | Val Loss: D=0.3738 | Val Accuracy: 98.13%
# Rank 0 | Epoch 85/1000 | Train Loss: D=0.4384, G=0.9639 | Train Accuracy: 96.41% | Val Loss: D=0.4960 | Val Accuracy: 97.94%
# Rank 0 | Epoch 86/1000 | Train Loss: D=0.4344, G=0.9673 | Train Accuracy: 96.54% | Val Loss: D=0.3326 | Val Accuracy: 98.22%
# Rank 0 | Epoch 87/1000 | Train Loss: D=0.4443, G=0.9351 | Train Accuracy: 96.37% | Val Loss: D=0.3354 | Val Accuracy: 98.23%
# Rank 0 | Epoch 88/1000 | Train Loss: D=0.4458, G=0.8592 | Train Accuracy: 96.36% | Val Loss: D=0.3343 | Val Accuracy: 98.24%
# Rank 0 | Epoch 89/1000 | Train Loss: D=0.4616, G=0.8624 | Train Accuracy: 96.09% | Val Loss: D=0.3871 | Val Accuracy: 98.06%
# Rank 0 | Epoch 90/1000 | Train Loss: D=0.5082, G=0.7227 | Train Accuracy: 95.54% | Val Loss: D=0.3450 | Val Accuracy: 98.22%
# Rank 0 | Epoch 91/1000 | Train Loss: D=0.4167, G=0.9814 | Train Accuracy: 96.83% | Val Loss: D=0.3505 | Val Accuracy: 98.16%
# Rank 0 | Epoch 92/1000 | Train Loss: D=0.4545, G=0.8801 | Train Accuracy: 96.44% | Val Loss: D=0.3719 | Val Accuracy: 98.20%
# Rank 0 | Epoch 93/1000 | Train Loss: D=0.4658, G=0.8534 | Train Accuracy: 96.12% | Val Loss: D=0.3394 | Val Accuracy: 98.22%
# Rank 0 | Epoch 94/1000 | Train Loss: D=0.4820, G=0.7704 | Train Accuracy: 95.93% | Val Loss: D=0.3322 | Val Accuracy: 98.21%
# Rank 0 | Epoch 95/1000 | Train Loss: D=0.5060, G=0.7066 | Train Accuracy: 95.76% | Val Loss: D=0.3409 | Val Accuracy: 98.20%
# Rank 0 | Epoch 96/1000 | Train Loss: D=0.4753, G=0.8080 | Train Accuracy: 95.97% | Val Loss: D=0.3328 | Val Accuracy: 98.22%
# Rank 0 | Epoch 97/1000 | Train Loss: D=0.5031, G=0.7323 | Train Accuracy: 95.59% | Val Loss: D=0.3464 | Val Accuracy: 98.19%
# Rank 0 | Epoch 98/1000 | Train Loss: D=0.5038, G=0.6967 | Train Accuracy: 95.80% | Val Loss: D=0.3788 | Val Accuracy: 98.13%
# Rank 0 | Epoch 99/1000 | Train Loss: D=0.5015, G=0.7146 | Train Accuracy: 95.83% | Val Loss: D=0.3374 | Val Accuracy: 98.24%
# Rank 0 | Epoch 100/1000 | Train Loss: D=0.4695, G=0.7753 | Train Accuracy: 96.33% | Val Loss: D=0.3337 | Val Accuracy: 98.23%
# Rank 0 | Epoch 101/1000 | Train Loss: D=0.4570, G=0.7481 | Train Accuracy: 96.39% | Val Loss: D=0.3393 | Val Accuracy: 98.22%
# Rank 0 | Epoch 102/1000 | Train Loss: D=0.5129, G=0.6849 | Train Accuracy: 95.78% | Val Loss: D=0.3610 | Val Accuracy: 98.19%
# Rank 0 | Epoch 103/1000 | Train Loss: D=0.5127, G=0.7537 | Train Accuracy: 95.78% | Val Loss: D=0.3312 | Val Accuracy: 98.23%
# Rank 0 | Epoch 104/1000 | Train Loss: D=0.5389, G=0.6300 | Train Accuracy: 95.26% | Val Loss: D=0.3518 | Val Accuracy: 98.10%
# Rank 0 | Epoch 105/1000 | Train Loss: D=0.4970, G=0.6683 | Train Accuracy: 95.84% | Val Loss: D=0.3427 | Val Accuracy: 98.21%
# Rank 0 | Epoch 106/1000 | Train Loss: D=0.4943, G=0.6473 | Train Accuracy: 95.93% | Val Loss: D=0.3359 | Val Accuracy: 98.22%
# Rank 0 | Epoch 107/1000 | Train Loss: D=0.5240, G=0.6225 | Train Accuracy: 95.46% | Val Loss: D=0.3345 | Val Accuracy: 98.22%
# Rank 0 | Epoch 108/1000 | Train Loss: D=0.5023, G=0.6422 | Train Accuracy: 96.00% | Val Loss: D=0.3325 | Val Accuracy: 98.22%
# Rank 0 | Epoch 109/1000 | Train Loss: D=0.5125, G=0.6652 | Train Accuracy: 95.74% | Val Loss: D=0.3341 | Val Accuracy: 98.22%
# Rank 0 | Epoch 110/1000 | Train Loss: D=0.5172, G=0.6075 | Train Accuracy: 96.01% | Val Loss: D=0.3311 | Val Accuracy: 98.23%
# Rank 0 | Epoch 111/1000 | Train Loss: D=0.5249, G=0.6475 | Train Accuracy: 95.51% | Val Loss: D=0.3321 | Val Accuracy: 98.23%
# Rank 0 | Epoch 112/1000 | Train Loss: D=0.5359, G=0.6159 | Train Accuracy: 95.41% | Val Loss: D=0.3392 | Val Accuracy: 98.22%
# Rank 0 | Epoch 113/1000 | Train Loss: D=0.5214, G=0.5961 | Train Accuracy: 95.62% | Val Loss: D=0.3329 | Val Accuracy: 98.21%
# Rank 0 | Epoch 114/1000 | Train Loss: D=0.5225, G=0.6307 | Train Accuracy: 95.62% | Val Loss: D=0.3671 | Val Accuracy: 98.14%
# Rank 0 | Epoch 115/1000 | Train Loss: D=0.5284, G=0.6395 | Train Accuracy: 95.75% | Val Loss: D=0.3586 | Val Accuracy: 98.17%
# Rank 0 | Epoch 116/1000 | Train Loss: D=0.5443, G=0.6161 | Train Accuracy: 95.07% | Val Loss: D=0.3441 | Val Accuracy: 98.21%
# Rank 0 | Epoch 117/1000 | Train Loss: D=0.5343, G=0.6030 | Train Accuracy: 95.23% | Val Loss: D=0.3453 | Val Accuracy: 98.20%
# Rank 0 | Epoch 118/1000 | Train Loss: D=0.5963, G=0.5085 | Train Accuracy: 94.61% | Val Loss: D=0.3371 | Val Accuracy: 98.23%
# Rank 0 | Epoch 119/1000 | Train Loss: D=0.5702, G=0.5339 | Train Accuracy: 95.25% | Val Loss: D=0.3322 | Val Accuracy: 98.24%
# Rank 0 | Epoch 120/1000 | Train Loss: D=0.5577, G=0.5539 | Train Accuracy: 95.11% | Val Loss: D=0.3309 | Val Accuracy: 98.24%
# Rank 0 | Epoch 121/1000 | Train Loss: D=0.5229, G=0.6236 | Train Accuracy: 95.59% | Val Loss: D=0.3424 | Val Accuracy: 98.20%
# Rank 0 | Epoch 122/1000 | Train Loss: D=0.5698, G=0.4985 | Train Accuracy: 94.82% | Val Loss: D=0.3438 | Val Accuracy: 98.19%
# Rank 0 | Epoch 123/1000 | Train Loss: D=0.5448, G=0.5505 | Train Accuracy: 95.57% | Val Loss: D=0.3341 | Val Accuracy: 98.22%
# Rank 0 | Epoch 124/1000 | Train Loss: D=0.5408, G=0.6043 | Train Accuracy: 94.79% | Val Loss: D=0.3850 | Val Accuracy: 98.18%
# Rank 0 | Epoch 125/1000 | Train Loss: D=0.5598, G=0.5067 | Train Accuracy: 95.21% | Val Loss: D=0.3474 | Val Accuracy: 98.20%
# Rank 0 | Epoch 126/1000 | Train Loss: D=0.5741, G=0.4918 | Train Accuracy: 94.65% | Val Loss: D=0.3448 | Val Accuracy: 98.22%
# Rank 0 | Epoch 127/1000 | Train Loss: D=0.5427, G=0.5266 | Train Accuracy: 95.06% | Val Loss: D=0.3379 | Val Accuracy: 98.22%
# Rank 0 | Epoch 128/1000 | Train Loss: D=0.5697, G=0.5002 | Train Accuracy: 95.20% | Val Loss: D=0.3392 | Val Accuracy: 98.21%
# Rank 0 | Epoch 129/1000 | Train Loss: D=0.5684, G=0.5074 | Train Accuracy: 94.73% | Val Loss: D=0.3359 | Val Accuracy: 98.21%
# Rank 0 | Epoch 130/1000 | Train Loss: D=0.5309, G=0.5432 | Train Accuracy: 95.61% | Val Loss: D=0.3465 | Val Accuracy: 98.19%
# Rank 0 | Epoch 131/1000 | Train Loss: D=0.5408, G=0.5149 | Train Accuracy: 95.45% | Val Loss: D=0.3444 | Val Accuracy: 98.18%
# Rank 0 | Epoch 132/1000 | Train Loss: D=0.5642, G=0.5314 | Train Accuracy: 95.22% | Val Loss: D=0.3313 | Val Accuracy: 98.24%
# Rank 0 | Epoch 133/1000 | Train Loss: D=0.5625, G=0.5285 | Train Accuracy: 94.95% | Val Loss: D=0.3515 | Val Accuracy: 98.20%
# Rank 0 | Epoch 134/1000 | Train Loss: D=0.5622, G=0.5132 | Train Accuracy: 95.13% | Val Loss: D=0.3508 | Val Accuracy: 98.18%
# Rank 0 | Epoch 135/1000 | Train Loss: D=0.5398, G=0.5438 | Train Accuracy: 95.39% | Val Loss: D=0.3332 | Val Accuracy: 98.19%
# Rank 0 | Epoch 136/1000 | Train Loss: D=0.5475, G=0.5174 | Train Accuracy: 95.42% | Val Loss: D=0.3343 | Val Accuracy: 98.20%
# Rank 0 | Epoch 137/1000 | Train Loss: D=0.5218, G=0.6122 | Train Accuracy: 95.46% | Val Loss: D=0.3972 | Val Accuracy: 98.16%
# Rank 0 | Epoch 138/1000 | Train Loss: D=0.5612, G=0.5161 | Train Accuracy: 94.80% | Val Loss: D=0.3387 | Val Accuracy: 98.18%
# Rank 0 | Epoch 139/1000 | Train Loss: D=0.5373, G=0.5446 | Train Accuracy: 95.44% | Val Loss: D=0.3344 | Val Accuracy: 98.23%
# Rank 0 | Epoch 140/1000 | Train Loss: D=0.5458, G=0.5223 | Train Accuracy: 95.07% | Val Loss: D=0.3331 | Val Accuracy: 98.21%
# Rank 0 | Epoch 141/1000 | Train Loss: D=0.5519, G=0.5397 | Train Accuracy: 95.28% | Val Loss: D=0.3489 | Val Accuracy: 98.22%
# Rank 0 | Epoch 142/1000 | Train Loss: D=0.5353, G=0.5139 | Train Accuracy: 94.92% | Val Loss: D=0.3491 | Val Accuracy: 98.16%
# Rank 0 | Epoch 143/1000 | Train Loss: D=0.5387, G=0.5175 | Train Accuracy: 95.17% | Val Loss: D=0.3320 | Val Accuracy: 98.21%
# Rank 0 | Epoch 144/1000 | Train Loss: D=0.5387, G=0.5231 | Train Accuracy: 95.10% | Val Loss: D=0.3322 | Val Accuracy: 98.24%
# Rank 0 | Epoch 145/1000 | Train Loss: D=0.5152, G=0.5412 | Train Accuracy: 95.51% | Val Loss: D=0.3340 | Val Accuracy: 98.21%
# Rank 0 | Epoch 146/1000 | Train Loss: D=0.5503, G=0.5529 | Train Accuracy: 94.36% | Val Loss: D=0.3347 | Val Accuracy: 98.21%
# Rank 0 | Epoch 147/1000 | Train Loss: D=0.5255, G=0.5419 | Train Accuracy: 95.12% | Val Loss: D=0.3405 | Val Accuracy: 98.21%
# Rank 0 | Epoch 148/1000 | Train Loss: D=0.5113, G=0.5663 | Train Accuracy: 95.29% | Val Loss: D=0.3559 | Val Accuracy: 98.21%
# Rank 0 | Epoch 149/1000 | Train Loss: D=0.5313, G=0.5457 | Train Accuracy: 95.32% | Val Loss: D=0.3355 | Val Accuracy: 98.18%
# Rank 0 | Epoch 150/1000 | Train Loss: D=0.5364, G=0.5781 | Train Accuracy: 95.02% | Val Loss: D=0.3406 | Val Accuracy: 98.17%
# Rank 0 | Epoch 151/1000 | Train Loss: D=0.5263, G=0.5461 | Train Accuracy: 95.18% | Val Loss: D=0.3398 | Val Accuracy: 98.22%
# Rank 0 | Epoch 152/1000 | Train Loss: D=0.5270, G=0.5422 | Train Accuracy: 94.90% | Val Loss: D=0.3309 | Val Accuracy: 98.24%
# Rank 0 | Epoch 153/1000 | Train Loss: D=0.5022, G=0.5869 | Train Accuracy: 95.24% | Val Loss: D=0.3350 | Val Accuracy: 98.20%
# Rank 0 | Epoch 154/1000 | Train Loss: D=0.5264, G=0.6071 | Train Accuracy: 95.18% | Val Loss: D=0.3607 | Val Accuracy: 98.19%
# Rank 0 | Epoch 155/1000 | Train Loss: D=0.5179, G=0.5816 | Train Accuracy: 94.99% | Val Loss: D=0.3490 | Val Accuracy: 98.20%
# Rank 0 | Epoch 156/1000 | Train Loss: D=0.5193, G=0.5836 | Train Accuracy: 95.03% | Val Loss: D=0.3338 | Val Accuracy: 98.04%
# Rank 0 | Epoch 157/1000 | Train Loss: D=0.5490, G=0.5933 | Train Accuracy: 94.54% | Val Loss: D=0.3331 | Val Accuracy: 98.22%
# Rank 0 | Epoch 158/1000 | Train Loss: D=0.5186, G=0.5936 | Train Accuracy: 95.15% | Val Loss: D=0.3315 | Val Accuracy: 98.22%
# Rank 0 | Epoch 159/1000 | Train Loss: D=0.5365, G=0.6117 | Train Accuracy: 94.68% | Val Loss: D=0.3309 | Val Accuracy: 98.24%
# Rank 0 | Epoch 160/1000 | Train Loss: D=0.5249, G=0.5553 | Train Accuracy: 94.99% | Val Loss: D=0.3386 | Val Accuracy: 98.20%
# Rank 0 | Epoch 161/1000 | Train Loss: D=0.5152, G=0.5625 | Train Accuracy: 95.16% | Val Loss: D=0.3311 | Val Accuracy: 98.23%
# Rank 0 | Epoch 162/1000 | Train Loss: D=0.5249, G=0.5871 | Train Accuracy: 94.81% | Val Loss: D=0.3471 | Val Accuracy: 98.23%
# Rank 0 | Epoch 163/1000 | Train Loss: D=0.5246, G=0.5311 | Train Accuracy: 94.92% | Val Loss: D=0.3586 | Val Accuracy: 98.16%
# Rank 0 | Epoch 164/1000 | Train Loss: D=0.5318, G=0.5660 | Train Accuracy: 95.08% | Val Loss: D=0.3374 | Val Accuracy: 98.22%
# Rank 0 | Epoch 166/1000 | Train Loss: D=0.5285, G=0.6114 | Train Accuracy: 94.94% | Val Loss: D=0.3319 | Val Accuracy: 98.24%
# Rank 0 | Epoch 167/1000 | Train Loss: D=0.5124, G=0.5780 | Train Accuracy: 95.56% | Val Loss: D=0.3346 | Val Accuracy: 98.20%
# Rank 0 | Epoch 168/1000 | Train Loss: D=0.4971, G=0.6499 | Train Accuracy: 95.75% | Val Loss: D=0.3322 | Val Accuracy: 98.23%
# Rank 0 | Epoch 169/1000 | Train Loss: D=0.5266, G=0.6255 | Train Accuracy: 95.30% | Val Loss: D=0.3366 | Val Accuracy: 98.19%
# Rank 0 | Epoch 170/1000 | Train Loss: D=0.5203, G=0.6223 | Train Accuracy: 95.17% | Val Loss: D=0.3463 | Val Accuracy: 98.19%
# Rank 0 | Epoch 171/1000 | Train Loss: D=0.5144, G=0.5566 | Train Accuracy: 95.02% | Val Loss: D=0.3564 | Val Accuracy: 98.19%
# Rank 0 | Epoch 172/1000 | Train Loss: D=0.5329, G=0.5956 | Train Accuracy: 95.18% | Val Loss: D=0.3575 | Val Accuracy: 98.19%
# Rank 0 | Epoch 173/1000 | Train Loss: D=0.5208, G=0.5869 | Train Accuracy: 95.26% | Val Loss: D=0.3500 | Val Accuracy: 98.21%
# Rank 0 | Epoch 174/1000 | Train Loss: D=0.5369, G=0.5911 | Train Accuracy: 94.65% | Val Loss: D=0.3628 | Val Accuracy: 98.19%
# Rank 0 | Epoch 175/1000 | Train Loss: D=0.5482, G=0.5151 | Train Accuracy: 94.60% | Val Loss: D=0.3614 | Val Accuracy: 98.20%
# Rank 0 | Epoch 176/1000 | Train Loss: D=0.5068, G=0.6100 | Train Accuracy: 95.31% | Val Loss: D=0.3345 | Val Accuracy: 98.18%
# Rank 0 | Epoch 177/1000 | Train Loss: D=0.5038, G=0.6051 | Train Accuracy: 95.52% | Val Loss: D=0.3311 | Val Accuracy: 98.24%
# Rank 0 | Epoch 178/1000 | Train Loss: D=0.5045, G=0.6465 | Train Accuracy: 95.30% | Val Loss: D=0.3352 | Val Accuracy: 98.22%
# Rank 0 | Epoch 179/1000 | Train Loss: D=0.5101, G=0.5979 | Train Accuracy: 95.45% | Val Loss: D=0.3470 | Val Accuracy: 98.20%
# Rank 0 | Epoch 180/1000 | Train Loss: D=0.5266, G=0.6015 | Train Accuracy: 95.17% | Val Loss: D=0.3482 | Val Accuracy: 98.20%
# Rank 0 | Epoch 181/1000 | Train Loss: D=0.5029, G=0.5689 | Train Accuracy: 95.05% | Val Loss: D=0.3494 | Val Accuracy: 98.21%
# Rank 0 | Epoch 182/1000 | Train Loss: D=0.5183, G=0.6308 | Train Accuracy: 95.04% | Val Loss: D=0.3366 | Val Accuracy: 98.22%
# Rank 0 | Epoch 183/1000 | Train Loss: D=0.5038, G=0.6258 | Train Accuracy: 95.22% | Val Loss: D=0.3469 | Val Accuracy: 98.21%
# Rank 0 | Epoch 184/1000 | Train Loss: D=0.5054, G=0.5941 | Train Accuracy: 95.29% | Val Loss: D=0.3812 | Val Accuracy: 98.13%
# Rank 0 | Epoch 185/1000 | Train Loss: D=0.5062, G=0.6121 | Train Accuracy: 95.36% | Val Loss: D=0.3356 | Val Accuracy: 98.23%
# Rank 0 | Epoch 186/1000 | Train Loss: D=0.4614, G=0.7130 | Train Accuracy: 95.80% | Val Loss: D=0.3345 | Val Accuracy: 98.23%
# Rank 0 | Epoch 187/1000 | Train Loss: D=0.4930, G=0.7024 | Train Accuracy: 95.79% | Val Loss: D=0.3316 | Val Accuracy: 98.24%
# Rank 0 | Epoch 188/1000 | Train Loss: D=0.4950, G=0.6854 | Train Accuracy: 95.80% | Val Loss: D=0.3327 | Val Accuracy: 98.23%
# Rank 0 | Epoch 189/1000 | Train Loss: D=0.5001, G=0.6006 | Train Accuracy: 95.15% | Val Loss: D=0.3325 | Val Accuracy: 98.21%
# Rank 0 | Epoch 190/1000 | Train Loss: D=0.4926, G=0.6108 | Train Accuracy: 95.30% | Val Loss: D=0.3328 | Val Accuracy: 98.22%
# Rank 0 | Epoch 191/1000 | Train Loss: D=0.4760, G=0.6767 | Train Accuracy: 95.45% | Val Loss: D=0.3416 | Val Accuracy: 98.23%
# Rank 0 | Epoch 192/1000 | Train Loss: D=0.4960, G=0.6763 | Train Accuracy: 95.31% | Val Loss: D=0.3318 | Val Accuracy: 98.23%
# Rank 0 | Epoch 193/1000 | Train Loss: D=0.4743, G=0.6759 | Train Accuracy: 95.72% | Val Loss: D=0.3325 | Val Accuracy: 98.21%
# Rank 0 | Epoch 194/1000 | Train Loss: D=0.4873, G=0.6989 | Train Accuracy: 95.30% | Val Loss: D=0.3313 | Val Accuracy: 98.23%
# Rank 0 | Epoch 195/1000 | Train Loss: D=0.4919, G=0.7149 | Train Accuracy: 95.60% | Val Loss: D=0.3312 | Val Accuracy: 98.24%
# Rank 0 | Epoch 196/1000 | Train Loss: D=0.4938, G=0.6959 | Train Accuracy: 95.17% | Val Loss: D=0.3315 | Val Accuracy: 98.24%
# Rank 0 | Epoch 197/1000 | Train Loss: D=0.4905, G=0.6633 | Train Accuracy: 95.39% | Val Loss: D=0.3436 | Val Accuracy: 98.18%
# Rank 0 | Epoch 198/1000 | Train Loss: D=0.4979, G=0.6326 | Train Accuracy: 95.25% | Val Loss: D=0.3629 | Val Accuracy: 98.16%
# Rank 0 | Epoch 199/1000 | Train Loss: D=0.4723, G=0.7080 | Train Accuracy: 95.82% | Val Loss: D=0.3320 | Val Accuracy: 98.21%
# Rank 0 | Epoch 200/1000 | Train Loss: D=0.4942, G=0.6441 | Train Accuracy: 95.47% | Val Loss: D=0.3313 | Val Accuracy: 98.24%
# Rank 0 | Epoch 201/1000 | Train Loss: D=0.4934, G=0.6289 | Train Accuracy: 95.81% | Val Loss: D=0.3328 | Val Accuracy: 98.23%
# Rank 0 | Epoch 202/1000 | Train Loss: D=0.4881, G=0.6458 | Train Accuracy: 95.74% | Val Loss: D=0.3330 | Val Accuracy: 98.23%
# Rank 0 | Epoch 203/1000 | Train Loss: D=0.4927, G=0.6859 | Train Accuracy: 95.49% | Val Loss: D=0.3338 | Val Accuracy: 98.21%
# Rank 0 | Epoch 204/1000 | Train Loss: D=0.4735, G=0.7147 | Train Accuracy: 95.82% | Val Loss: D=0.3563 | Val Accuracy: 98.19%
# Rank 0 | Epoch 205/1000 | Train Loss: D=0.4759, G=0.6821 | Train Accuracy: 95.84% | Val Loss: D=0.3629 | Val Accuracy: 98.16%
# Rank 0 | Epoch 206/1000 | Train Loss: D=0.4734, G=0.7572 | Train Accuracy: 95.60% | Val Loss: D=0.3683 | Val Accuracy: 98.14%
# Rank 0 | Epoch 207/1000 | Train Loss: D=0.4961, G=0.7096 | Train Accuracy: 95.20% | Val Loss: D=0.3328 | Val Accuracy: 98.24%
# Rank 0 | Epoch 208/1000 | Train Loss: D=0.4818, G=0.6768 | Train Accuracy: 95.81% | Val Loss: D=0.3338 | Val Accuracy: 98.23%
# Rank 0 | Epoch 209/1000 | Train Loss: D=0.4811, G=0.6807 | Train Accuracy: 95.62% | Val Loss: D=0.3458 | Val Accuracy: 98.24%
# Rank 0 | Epoch 210/1000 | Train Loss: D=0.4752, G=0.7225 | Train Accuracy: 95.68% | Val Loss: D=0.3558 | Val Accuracy: 98.16%
# Rank 0 | Epoch 211/1000 | Train Loss: D=0.4935, G=0.7356 | Train Accuracy: 95.40% | Val Loss: D=0.3445 | Val Accuracy: 98.21%
# Rank 0 | Epoch 212/1000 | Train Loss: D=0.4567, G=0.8173 | Train Accuracy: 96.11% | Val Loss: D=0.3725 | Val Accuracy: 98.18%
# Rank 0 | Epoch 213/1000 | Train Loss: D=0.4398, G=0.9384 | Train Accuracy: 96.46% | Val Loss: D=0.3369 | Val Accuracy: 98.20%
# Rank 0 | Epoch 214/1000 | Train Loss: D=0.4705, G=0.7266 | Train Accuracy: 95.72% | Val Loss: D=0.3369 | Val Accuracy: 98.19%
# Rank 0 | Epoch 215/1000 | Train Loss: D=0.4905, G=0.7526 | Train Accuracy: 95.61% | Val Loss: D=0.3425 | Val Accuracy: 98.23%
# Rank 0 | Epoch 216/1000 | Train Loss: D=0.4743, G=0.7693 | Train Accuracy: 95.89% | Val Loss: D=0.3727 | Val Accuracy: 98.13%
# Rank 0 | Epoch 217/1000 | Train Loss: D=0.4868, G=0.6971 | Train Accuracy: 95.67% | Val Loss: D=0.3942 | Val Accuracy: 98.14%
# Rank 0 | Epoch 218/1000 | Train Loss: D=0.4991, G=0.6486 | Train Accuracy: 95.37% | Val Loss: D=0.3384 | Val Accuracy: 98.19%
# Rank 0 | Epoch 219/1000 | Train Loss: D=0.4764, G=0.6890 | Train Accuracy: 95.57% | Val Loss: D=0.3331 | Val Accuracy: 98.22%
# Rank 0 | Epoch 220/1000 | Train Loss: D=0.4510, G=0.7451 | Train Accuracy: 96.27% | Val Loss: D=0.3538 | Val Accuracy: 98.18%
# Rank 0 | Epoch 221/1000 | Train Loss: D=0.4685, G=0.7177 | Train Accuracy: 95.92% | Val Loss: D=0.3471 | Val Accuracy: 98.19%
# Rank 0 | Epoch 222/1000 | Train Loss: D=0.4942, G=0.6654 | Train Accuracy: 95.39% | Val Loss: D=0.3454 | Val Accuracy: 98.20%
# Rank 0 | Epoch 223/1000 | Train Loss: D=0.4802, G=0.7022 | Train Accuracy: 95.44% | Val Loss: D=0.3322 | Val Accuracy: 98.22%
# Rank 0 | Epoch 224/1000 | Train Loss: D=0.4527, G=0.7919 | Train Accuracy: 95.68% | Val Loss: D=0.3378 | Val Accuracy: 98.22%
# Rank 0 | Epoch 225/1000 | Train Loss: D=0.4830, G=0.7447 | Train Accuracy: 95.62% | Val Loss: D=0.3345 | Val Accuracy: 98.22%
# Rank 0 | Epoch 226/1000 | Train Loss: D=0.4845, G=0.6654 | Train Accuracy: 95.88% | Val Loss: D=0.3334 | Val Accuracy: 98.23%
# Rank 0 | Epoch 227/1000 | Train Loss: D=0.4805, G=0.7070 | Train Accuracy: 95.76% | Val Loss: D=0.3335 | Val Accuracy: 98.22%
# Rank 0 | Epoch 228/1000 | Train Loss: D=0.4820, G=0.7514 | Train Accuracy: 95.51% | Val Loss: D=0.3325 | Val Accuracy: 98.24%
# Rank 0 | Epoch 229/1000 | Train Loss: D=0.4808, G=0.6720 | Train Accuracy: 95.55% | Val Loss: D=0.3527 | Val Accuracy: 98.20%
# Rank 0 | Epoch 230/1000 | Train Loss: D=0.4740, G=0.6983 | Train Accuracy: 95.57% | Val Loss: D=0.3313 | Val Accuracy: 98.23%
# Rank 0 | Epoch 231/1000 | Train Loss: D=0.5008, G=0.6719 | Train Accuracy: 95.47% | Val Loss: D=0.3448 | Val Accuracy: 98.22%
# Rank 0 | Epoch 232/1000 | Train Loss: D=0.4887, G=0.6705 | Train Accuracy: 95.56% | Val Loss: D=0.3390 | Val Accuracy: 98.21%
# Rank 0 | Epoch 233/1000 | Train Loss: D=0.4931, G=0.6673 | Train Accuracy: 95.31% | Val Loss: D=0.3418 | Val Accuracy: 98.20%
# Rank 0 | Epoch 234/1000 | Train Loss: D=0.4812, G=0.6887 | Train Accuracy: 95.45% | Val Loss: D=0.3314 | Val Accuracy: 98.23%
# Rank 0 | Epoch 235/1000 | Train Loss: D=0.4876, G=0.7352 | Train Accuracy: 95.14% | Val Loss: D=0.3426 | Val Accuracy: 98.20%
# Rank 0 | Epoch 236/1000 | Train Loss: D=0.4528, G=0.7569 | Train Accuracy: 95.98% | Val Loss: D=0.3592 | Val Accuracy: 98.16%
# Rank 0 | Epoch 237/1000 | Train Loss: D=0.4665, G=0.7048 | Train Accuracy: 95.66% | Val Loss: D=0.3784 | Val Accuracy: 98.03%
# Rank 0 | Epoch 238/1000 | Train Loss: D=0.4674, G=0.7874 | Train Accuracy: 95.87% | Val Loss: D=0.3638 | Val Accuracy: 98.11%
# Rank 0 | Epoch 239/1000 | Train Loss: D=0.4716, G=0.7163 | Train Accuracy: 95.79% | Val Loss: D=0.3627 | Val Accuracy: 98.19%
# Rank 0 | Epoch 240/1000 | Train Loss: D=0.4541, G=0.8256 | Train Accuracy: 95.91% | Val Loss: D=0.3343 | Val Accuracy: 98.17%
# Rank 0 | Epoch 241/1000 | Train Loss: D=0.4856, G=0.7856 | Train Accuracy: 95.86% | Val Loss: D=0.3605 | Val Accuracy: 98.16%
# Rank 0 | Epoch 242/1000 | Train Loss: D=0.4652, G=0.8094 | Train Accuracy: 96.08% | Val Loss: D=0.3340 | Val Accuracy: 98.22%
# Rank 0 | Epoch 243/1000 | Train Loss: D=0.4690, G=0.7857 | Train Accuracy: 96.28% | Val Loss: D=0.3311 | Val Accuracy: 98.24%
# Rank 0 | Epoch 244/1000 | Train Loss: D=0.4501, G=0.7859 | Train Accuracy: 96.37% | Val Loss: D=0.3319 | Val Accuracy: 98.22%
# Rank 0 | Epoch 245/1000 | Train Loss: D=0.4750, G=0.7285 | Train Accuracy: 95.50% | Val Loss: D=0.3440 | Val Accuracy: 98.22%
# Rank 0 | Epoch 246/1000 | Train Loss: D=0.4738, G=0.7340 | Train Accuracy: 95.52% | Val Loss: D=0.3396 | Val Accuracy: 98.19%
# Rank 0 | Epoch 247/1000 | Train Loss: D=0.4734, G=0.7374 | Train Accuracy: 95.73% | Val Loss: D=0.3311 | Val Accuracy: 98.24%
# Rank 0 | Epoch 248/1000 | Train Loss: D=0.4703, G=0.7206 | Train Accuracy: 96.21% | Val Loss: D=0.3489 | Val Accuracy: 98.21%
# Rank 0 | Epoch 249/1000 | Train Loss: D=0.4672, G=0.7389 | Train Accuracy: 95.67% | Val Loss: D=0.3309 | Val Accuracy: 98.24%
# Rank 0 | Epoch 250/1000 | Train Loss: D=0.4906, G=0.6806 | Train Accuracy: 95.30% | Val Loss: D=0.3389 | Val Accuracy: 98.24%
# Rank 0 | Epoch 251/1000 | Train Loss: D=0.4684, G=0.6629 | Train Accuracy: 95.75% | Val Loss: D=0.3310 | Val Accuracy: 98.24%
# Rank 0 | Epoch 252/1000 | Train Loss: D=0.4858, G=0.6395 | Train Accuracy: 95.22% | Val Loss: D=0.3447 | Val Accuracy: 98.22%
# Rank 0 | Epoch 253/1000 | Train Loss: D=0.4904, G=0.7025 | Train Accuracy: 95.30% | Val Loss: D=0.3350 | Val Accuracy: 98.21%
# Rank 0 | Epoch 254/1000 | Train Loss: D=0.4787, G=0.7279 | Train Accuracy: 95.46% | Val Loss: D=0.3325 | Val Accuracy: 98.23%
# Rank 0 | Epoch 255/1000 | Train Loss: D=0.4645, G=0.6831 | Train Accuracy: 95.63% | Val Loss: D=0.3500 | Val Accuracy: 98.21%
# Rank 0 | Epoch 256/1000 | Train Loss: D=0.4596, G=0.7096 | Train Accuracy: 96.07% | Val Loss: D=0.3411 | Val Accuracy: 98.21%
# Rank 0 | Epoch 257/1000 | Train Loss: D=0.4640, G=0.7869 | Train Accuracy: 95.86% | Val Loss: D=0.3462 | Val Accuracy: 98.22%
# Rank 0 | Epoch 258/1000 | Train Loss: D=0.4519, G=0.7973 | Train Accuracy: 95.90% | Val Loss: D=0.3312 | Val Accuracy: 98.24%
# Rank 0 | Epoch 259/1000 | Train Loss: D=0.4612, G=0.7844 | Train Accuracy: 95.76% | Val Loss: D=0.3688 | Val Accuracy: 98.20%
# Rank 0 | Epoch 260/1000 | Train Loss: D=0.4376, G=0.8673 | Train Accuracy: 96.45% | Val Loss: D=0.3342 | Val Accuracy: 98.21%
# Rank 0 | Epoch 261/1000 | Train Loss: D=0.4493, G=0.7773 | Train Accuracy: 96.11% | Val Loss: D=0.3330 | Val Accuracy: 98.22%
# Rank 0 | Epoch 262/1000 | Train Loss: D=0.4338, G=0.8111 | Train Accuracy: 96.61% | Val Loss: D=0.3311 | Val Accuracy: 98.23%
# Rank 0 | Epoch 263/1000 | Train Loss: D=0.4772, G=0.7569 | Train Accuracy: 95.48% | Val Loss: D=0.3613 | Val Accuracy: 98.18%
# Rank 0 | Epoch 264/1000 | Train Loss: D=0.4891, G=0.6805 | Train Accuracy: 95.43% | Val Loss: D=0.3436 | Val Accuracy: 98.19%
# Rank 0 | Epoch 265/1000 | Train Loss: D=0.4703, G=0.7117 | Train Accuracy: 95.59% | Val Loss: D=0.3402 | Val Accuracy: 98.20%
# Rank 0 | Epoch 266/1000 | Train Loss: D=0.4698, G=0.6890 | Train Accuracy: 95.70% | Val Loss: D=0.3368 | Val Accuracy: 98.21%
# Rank 0 | Epoch 267/1000 | Train Loss: D=0.4637, G=0.7498 | Train Accuracy: 95.72% | Val Loss: D=0.3407 | Val Accuracy: 98.21%
# Rank 0 | Epoch 268/1000 | Train Loss: D=0.4709, G=0.7434 | Train Accuracy: 95.76% | Val Loss: D=0.3547 | Val Accuracy: 98.18%
# Rank 0 | Epoch 269/1000 | Train Loss: D=0.4952, G=0.6804 | Train Accuracy: 95.53% | Val Loss: D=0.3378 | Val Accuracy: 98.22%
# Rank 0 | Epoch 270/1000 | Train Loss: D=0.4698, G=0.6591 | Train Accuracy: 95.34% | Val Loss: D=0.3352 | Val Accuracy: 98.18%
# Rank 0 | Epoch 271/1000 | Train Loss: D=0.4494, G=0.7529 | Train Accuracy: 95.93% | Val Loss: D=0.3443 | Val Accuracy: 98.21%
# Rank 0 | Epoch 272/1000 | Train Loss: D=0.4832, G=0.7166 | Train Accuracy: 95.28% | Val Loss: D=0.3438 | Val Accuracy: 98.21%
# Rank 0 | Epoch 273/1000 | Train Loss: D=0.4766, G=0.6862 | Train Accuracy: 95.56% | Val Loss: D=0.3348 | Val Accuracy: 98.23%
# Rank 0 | Epoch 274/1000 | Train Loss: D=0.4702, G=0.7393 | Train Accuracy: 95.67% | Val Loss: D=0.3372 | Val Accuracy: 98.21%
# Rank 0 | Epoch 275/1000 | Train Loss: D=0.4525, G=0.7329 | Train Accuracy: 95.78% | Val Loss: D=0.3599 | Val Accuracy: 98.21%
# Rank 0 | Epoch 276/1000 | Train Loss: D=0.4571, G=0.7820 | Train Accuracy: 95.91% | Val Loss: D=0.3319 | Val Accuracy: 98.23%
# Rank 0 | Epoch 277/1000 | Train Loss: D=0.4641, G=0.7965 | Train Accuracy: 95.95% | Val Loss: D=0.3544 | Val Accuracy: 98.17%
# Rank 0 | Epoch 278/1000 | Train Loss: D=0.4534, G=0.7691 | Train Accuracy: 96.14% | Val Loss: D=0.3428 | Val Accuracy: 98.20%
# Rank 0 | Epoch 279/1000 | Train Loss: D=0.4542, G=0.7575 | Train Accuracy: 95.99% | Val Loss: D=0.3577 | Val Accuracy: 98.17%
# Rank 0 | Epoch 280/1000 | Train Loss: D=0.4720, G=0.7842 | Train Accuracy: 96.04% | Val Loss: D=0.3313 | Val Accuracy: 98.23%
# Rank 0 | Epoch 281/1000 | Train Loss: D=0.4671, G=0.8040 | Train Accuracy: 95.86% | Val Loss: D=0.3466 | Val Accuracy: 98.22%
# Rank 0 | Epoch 282/1000 | Train Loss: D=0.4785, G=0.7415 | Train Accuracy: 95.55% | Val Loss: D=0.3486 | Val Accuracy: 98.21%
# Rank 0 | Epoch 283/1000 | Train Loss: D=0.4411, G=0.8321 | Train Accuracy: 96.53% | Val Loss: D=0.3521 | Val Accuracy: 98.20%
# Rank 0 | Epoch 284/1000 | Train Loss: D=0.4540, G=0.8779 | Train Accuracy: 96.29% | Val Loss: D=0.3430 | Val Accuracy: 98.18%
# Rank 0 | Epoch 285/1000 | Train Loss: D=0.4674, G=0.8138 | Train Accuracy: 95.87% | Val Loss: D=0.3509 | Val Accuracy: 98.21%
# Rank 0 | Epoch 286/1000 | Train Loss: D=0.4633, G=0.7842 | Train Accuracy: 95.77% | Val Loss: D=0.3389 | Val Accuracy: 98.18%
# Rank 0 | Epoch 287/1000 | Train Loss: D=0.4405, G=0.8979 | Train Accuracy: 96.13% | Val Loss: D=0.3353 | Val Accuracy: 98.22%
# Rank 0 | Epoch 288/1000 | Train Loss: D=0.4399, G=0.8406 | Train Accuracy: 96.36% | Val Loss: D=0.3923 | Val Accuracy: 98.17%
# Rank 0 | Epoch 289/1000 | Train Loss: D=0.4371, G=0.8996 | Train Accuracy: 96.36% | Val Loss: D=0.3311 | Val Accuracy: 98.24%
# Rank 0 | Epoch 290/1000 | Train Loss: D=0.4435, G=0.9785 | Train Accuracy: 96.66% | Val Loss: D=0.3758 | Val Accuracy: 98.22%
# Rank 0 | Epoch 291/1000 | Train Loss: D=0.4427, G=0.9140 | Train Accuracy: 96.29% | Val Loss: D=0.3467 | Val Accuracy: 98.22%
# Rank 0 | Epoch 292/1000 | Train Loss: D=0.4445, G=0.8266 | Train Accuracy: 96.24% | Val Loss: D=0.3541 | Val Accuracy: 98.18%
# Rank 0 | Epoch 293/1000 | Train Loss: D=0.4328, G=0.9054 | Train Accuracy: 96.21% | Val Loss: D=0.3434 | Val Accuracy: 98.21%
# Rank 0 | Epoch 294/1000 | Train Loss: D=0.4264, G=1.0370 | Train Accuracy: 96.74% | Val Loss: D=0.3423 | Val Accuracy: 98.21%
# Rank 0 | Epoch 295/1000 | Train Loss: D=0.4657, G=0.8476 | Train Accuracy: 95.72% | Val Loss: D=0.3555 | Val Accuracy: 98.21%
# Rank 0 | Epoch 296/1000 | Train Loss: D=0.4617, G=0.7907 | Train Accuracy: 95.68% | Val Loss: D=0.3311 | Val Accuracy: 98.24%
# Rank 0 | Epoch 297/1000 | Train Loss: D=0.4548, G=0.7510 | Train Accuracy: 96.01% | Val Loss: D=0.3389 | Val Accuracy: 98.20%
# Rank 0 | Epoch 298/1000 | Train Loss: D=0.4570, G=0.7559 | Train Accuracy: 96.08% | Val Loss: D=0.3310 | Val Accuracy: 98.24%
# Rank 0 | Epoch 299/1000 | Train Loss: D=0.4483, G=0.8709 | Train Accuracy: 96.16% | Val Loss: D=0.3475 | Val Accuracy: 98.23%
# Rank 0 | Epoch 300/1000 | Train Loss: D=0.4426, G=0.8566 | Train Accuracy: 96.43% | Val Loss: D=0.3358 | Val Accuracy: 98.22%
# Rank 0 | Epoch 301/1000 | Train Loss: D=0.4285, G=0.8722 | Train Accuracy: 96.46% | Val Loss: D=0.3312 | Val Accuracy: 98.22%
# Rank 0 | Epoch 302/1000 | Train Loss: D=0.4716, G=0.8198 | Train Accuracy: 95.45% | Val Loss: D=0.3315 | Val Accuracy: 98.24%
# Rank 0 | Epoch 303/1000 | Train Loss: D=0.4378, G=0.8373 | Train Accuracy: 96.12% | Val Loss: D=0.3466 | Val Accuracy: 98.18%
# Rank 0 | Epoch 304/1000 | Train Loss: D=0.4479, G=0.8536 | Train Accuracy: 96.06% | Val Loss: D=0.3441 | Val Accuracy: 98.21%
# Rank 0 | Epoch 305/1000 | Train Loss: D=0.4449, G=0.8487 | Train Accuracy: 96.22% | Val Loss: D=0.3314 | Val Accuracy: 98.23%
# Rank 0 | Epoch 306/1000 | Train Loss: D=0.4404, G=0.8255 | Train Accuracy: 96.37% | Val Loss: D=0.3644 | Val Accuracy: 98.18%
# Rank 0 | Epoch 307/1000 | Train Loss: D=0.4482, G=0.8415 | Train Accuracy: 95.99% | Val Loss: D=0.3521 | Val Accuracy: 98.22%
# Rank 0 | Epoch 308/1000 | Train Loss: D=0.4448, G=0.8616 | Train Accuracy: 96.09% | Val Loss: D=0.3520 | Val Accuracy: 98.22%
# Rank 0 | Epoch 309/1000 | Train Loss: D=0.4350, G=0.8534 | Train Accuracy: 96.49% | Val Loss: D=0.3498 | Val Accuracy: 98.20%
# Rank 0 | Epoch 310/1000 | Train Loss: D=0.4203, G=0.9968 | Train Accuracy: 96.60% | Val Loss: D=0.3557 | Val Accuracy: 98.19%
# Rank 0 | Epoch 311/1000 | Train Loss: D=0.4424, G=0.9212 | Train Accuracy: 96.26% | Val Loss: D=0.3439 | Val Accuracy: 98.22%
# Rank 0 | Epoch 312/1000 | Train Loss: D=0.4397, G=0.8542 | Train Accuracy: 96.27% | Val Loss: D=0.3343 | Val Accuracy: 98.23%
# Rank 0 | Epoch 313/1000 | Train Loss: D=0.4500, G=0.8078 | Train Accuracy: 95.77% | Val Loss: D=0.3345 | Val Accuracy: 98.24%
# Rank 0 | Epoch 314/1000 | Train Loss: D=0.4483, G=0.8454 | Train Accuracy: 96.13% | Val Loss: D=0.3325 | Val Accuracy: 98.24%
# Rank 0 | Epoch 315/1000 | Train Loss: D=0.4395, G=0.8736 | Train Accuracy: 95.95% | Val Loss: D=0.3355 | Val Accuracy: 98.23%
# Rank 0 | Epoch 316/1000 | Train Loss: D=0.4493, G=0.8715 | Train Accuracy: 96.05% | Val Loss: D=0.3436 | Val Accuracy: 98.22%
# Rank 0 | Epoch 317/1000 | Train Loss: D=0.4313, G=0.9316 | Train Accuracy: 96.60% | Val Loss: D=0.3329 | Val Accuracy: 98.23%
# Rank 0 | Epoch 318/1000 | Train Loss: D=0.4553, G=0.8600 | Train Accuracy: 96.10% | Val Loss: D=0.3373 | Val Accuracy: 98.21%
# Rank 0 | Epoch 319/1000 | Train Loss: D=0.4471, G=0.7631 | Train Accuracy: 96.34% | Val Loss: D=0.3312 | Val Accuracy: 98.22%
# Rank 0 | Epoch 320/1000 | Train Loss: D=0.4370, G=0.8090 | Train Accuracy: 96.15% | Val Loss: D=0.3312 | Val Accuracy: 98.24%
# Rank 0 | Epoch 321/1000 | Train Loss: D=0.4554, G=0.8485 | Train Accuracy: 95.90% | Val Loss: D=0.3312 | Val Accuracy: 98.23%
# Rank 0 | Epoch 322/1000 | Train Loss: D=0.4034, G=1.4559 | Train Accuracy: 97.10% | Val Loss: D=0.3768 | Val Accuracy: 98.09%
# Rank 0 | Epoch 323/1000 | Train Loss: D=0.4353, G=0.9788 | Train Accuracy: 96.41% | Val Loss: D=0.3319 | Val Accuracy: 98.23%
# Rank 0 | Epoch 324/1000 | Train Loss: D=0.4236, G=0.8889 | Train Accuracy: 96.42% | Val Loss: D=0.3399 | Val Accuracy: 98.23%
# Rank 0 | Epoch 325/1000 | Train Loss: D=0.4586, G=0.7965 | Train Accuracy: 95.97% | Val Loss: D=0.3441 | Val Accuracy: 98.23%
# Rank 0 | Epoch 326/1000 | Train Loss: D=0.4372, G=0.8836 | Train Accuracy: 96.45% | Val Loss: D=0.3525 | Val Accuracy: 98.21%
# Rank 0 | Epoch 327/1000 | Train Loss: D=0.4387, G=0.9035 | Train Accuracy: 96.50% | Val Loss: D=0.3339 | Val Accuracy: 98.22%
# Rank 0 | Epoch 328/1000 | Train Loss: D=0.4428, G=0.8723 | Train Accuracy: 96.29% | Val Loss: D=0.3360 | Val Accuracy: 98.22%
# Rank 0 | Epoch 329/1000 | Train Loss: D=0.4328, G=0.8723 | Train Accuracy: 96.63% | Val Loss: D=0.3653 | Val Accuracy: 98.19%
# Rank 0 | Epoch 330/1000 | Train Loss: D=0.4370, G=0.8692 | Train Accuracy: 96.41% | Val Loss: D=0.3396 | Val Accuracy: 98.20%
# Rank 0 | Epoch 331/1000 | Train Loss: D=0.4494, G=0.8530 | Train Accuracy: 95.83% | Val Loss: D=0.3324 | Val Accuracy: 98.22%
# Rank 0 | Epoch 332/1000 | Train Loss: D=0.4386, G=0.9329 | Train Accuracy: 96.26% | Val Loss: D=0.3442 | Val Accuracy: 98.20%
# Rank 0 | Epoch 333/1000 | Train Loss: D=0.4480, G=0.8455 | Train Accuracy: 96.17% | Val Loss: D=0.3596 | Val Accuracy: 98.22%
# Rank 0 | Epoch 334/1000 | Train Loss: D=0.4067, G=1.0630 | Train Accuracy: 97.02% | Val Loss: D=0.3496 | Val Accuracy: 98.16%
# Rank 0 | Epoch 335/1000 | Train Loss: D=0.4184, G=1.2328 | Train Accuracy: 96.84% | Val Loss: D=0.3327 | Val Accuracy: 98.20%
# Rank 0 | Epoch 336/1000 | Train Loss: D=0.4298, G=1.0025 | Train Accuracy: 96.49% | Val Loss: D=0.3456 | Val Accuracy: 98.20%
# Rank 0 | Epoch 337/1000 | Train Loss: D=0.4293, G=0.9595 | Train Accuracy: 96.54% | Val Loss: D=0.3336 | Val Accuracy: 98.22%
# Rank 0 | Epoch 338/1000 | Train Loss: D=0.4480, G=0.8711 | Train Accuracy: 96.10% | Val Loss: D=0.3473 | Val Accuracy: 98.19%
# Rank 0 | Epoch 339/1000 | Train Loss: D=0.4334, G=0.8889 | Train Accuracy: 96.55% | Val Loss: D=0.3534 | Val Accuracy: 98.22%
# Rank 0 | Epoch 340/1000 | Train Loss: D=0.4383, G=0.9026 | Train Accuracy: 96.42% | Val Loss: D=0.3467 | Val Accuracy: 98.22%
# Rank 0 | Epoch 341/1000 | Train Loss: D=0.4473, G=0.8586 | Train Accuracy: 96.03% | Val Loss: D=0.3537 | Val Accuracy: 98.22%
# Rank 0 | Epoch 342/1000 | Train Loss: D=0.4345, G=0.8329 | Train Accuracy: 96.19% | Val Loss: D=0.3425 | Val Accuracy: 98.20%
# Rank 0 | Epoch 343/1000 | Train Loss: D=0.4235, G=0.8759 | Train Accuracy: 96.33% | Val Loss: D=0.3409 | Val Accuracy: 98.22%
# Rank 0 | Epoch 344/1000 | Train Loss: D=0.4421, G=0.9621 | Train Accuracy: 96.13% | Val Loss: D=0.3466 | Val Accuracy: 98.21%
# Rank 0 | Epoch 345/1000 | Train Loss: D=0.4439, G=0.8586 | Train Accuracy: 96.22% | Val Loss: D=0.3347 | Val Accuracy: 98.22%
# Rank 0 | Epoch 346/1000 | Train Loss: D=0.4433, G=0.8570 | Train Accuracy: 96.18% | Val Loss: D=0.3476 | Val Accuracy: 98.21%
# Rank 0 | Epoch 347/1000 | Train Loss: D=0.4533, G=0.7911 | Train Accuracy: 96.08% | Val Loss: D=0.3418 | Val Accuracy: 98.24%
# Rank 0 | Epoch 348/1000 | Train Loss: D=0.4545, G=0.7903 | Train Accuracy: 95.57% | Val Loss: D=0.3358 | Val Accuracy: 98.22%
# Rank 0 | Epoch 349/1000 | Train Loss: D=0.4356, G=0.8384 | Train Accuracy: 96.29% | Val Loss: D=0.3441 | Val Accuracy: 98.21%
# Rank 0 | Epoch 350/1000 | Train Loss: D=0.4583, G=0.7922 | Train Accuracy: 95.69% | Val Loss: D=0.3707 | Val Accuracy: 98.20%
# Rank 0 | Epoch 351/1000 | Train Loss: D=0.4500, G=0.8194 | Train Accuracy: 95.99% | Val Loss: D=0.3559 | Val Accuracy: 98.20%
# Rank 0 | Epoch 352/1000 | Train Loss: D=0.4524, G=0.7717 | Train Accuracy: 96.03% | Val Loss: D=0.3454 | Val Accuracy: 98.20%
# Rank 0 | Epoch 353/1000 | Train Loss: D=0.4381, G=0.8437 | Train Accuracy: 96.32% | Val Loss: D=0.3404 | Val Accuracy: 98.22%
# Rank 0 | Epoch 354/1000 | Train Loss: D=0.4587, G=0.9018 | Train Accuracy: 95.97% | Val Loss: D=0.3387 | Val Accuracy: 98.23%
# Rank 0 | Epoch 355/1000 | Train Loss: D=0.4382, G=0.9034 | Train Accuracy: 96.59% | Val Loss: D=0.3309 | Val Accuracy: 98.24%
# Rank 0 | Epoch 356/1000 | Train Loss: D=0.4011, G=1.0855 | Train Accuracy: 96.91% | Val Loss: D=0.3464 | Val Accuracy: 98.22%
# Rank 0 | Epoch 357/1000 | Train Loss: D=0.3690, G=2.2843 | Train Accuracy: 97.66% | Val Loss: D=0.3346 | Val Accuracy: 98.23%
# Rank 0 | Epoch 358/1000 | Train Loss: D=0.3391, G=2.2789 | Train Accuracy: 97.97% | Val Loss: D=0.3393 | Val Accuracy: 98.22%
# Rank 0 | Epoch 359/1000 | Train Loss: D=0.3910, G=1.7325 | Train Accuracy: 97.21% | Val Loss: D=0.3570 | Val Accuracy: 98.21%
# Rank 0 | Epoch 360/1000 | Train Loss: D=0.4667, G=0.8628 | Train Accuracy: 95.74% | Val Loss: D=0.3457 | Val Accuracy: 98.20%
# Rank 0 | Epoch 361/1000 | Train Loss: D=0.4586, G=0.8295 | Train Accuracy: 95.78% | Val Loss: D=0.3447 | Val Accuracy: 98.20%
# Rank 0 | Epoch 362/1000 | Train Loss: D=0.4596, G=0.7900 | Train Accuracy: 95.83% | Val Loss: D=0.3582 | Val Accuracy: 98.21%
# Rank 0 | Epoch 363/1000 | Train Loss: D=0.4326, G=0.9039 | Train Accuracy: 96.75% | Val Loss: D=0.3342 | Val Accuracy: 98.21%
# Rank 0 | Epoch 364/1000 | Train Loss: D=0.4083, G=1.0747 | Train Accuracy: 97.01% | Val Loss: D=0.3381 | Val Accuracy: 98.20%
# Rank 0 | Epoch 365/1000 | Train Loss: D=0.4561, G=0.8922 | Train Accuracy: 96.04% | Val Loss: D=0.3454 | Val Accuracy: 98.21%
# Rank 0 | Epoch 366/1000 | Train Loss: D=0.4499, G=0.8456 | Train Accuracy: 96.02% | Val Loss: D=0.3360 | Val Accuracy: 98.20%
# Rank 0 | Epoch 367/1000 | Train Loss: D=0.4507, G=0.8851 | Train Accuracy: 95.94% | Val Loss: D=0.3573 | Val Accuracy: 98.21%
# Rank 0 | Epoch 368/1000 | Train Loss: D=0.4229, G=0.9305 | Train Accuracy: 96.37% | Val Loss: D=0.3375 | Val Accuracy: 98.21%
# Rank 0 | Epoch 369/1000 | Train Loss: D=0.4094, G=0.9700 | Train Accuracy: 96.59% | Val Loss: D=0.3362 | Val Accuracy: 98.21%
# Rank 0 | Epoch 370/1000 | Train Loss: D=0.4570, G=0.8734 | Train Accuracy: 96.03% | Val Loss: D=0.3416 | Val Accuracy: 98.21%
# Rank 0 | Epoch 371/1000 | Train Loss: D=0.4521, G=0.7942 | Train Accuracy: 95.90% | Val Loss: D=0.3338 | Val Accuracy: 98.21%
# Rank 0 | Epoch 372/1000 | Train Loss: D=0.4373, G=0.7865 | Train Accuracy: 96.17% | Val Loss: D=0.3526 | Val Accuracy: 98.17%
# Rank 0 | Epoch 373/1000 | Train Loss: D=0.4246, G=0.8890 | Train Accuracy: 96.47% | Val Loss: D=0.3324 | Val Accuracy: 98.22%
# Rank 0 | Epoch 374/1000 | Train Loss: D=0.4585, G=0.8292 | Train Accuracy: 95.49% | Val Loss: D=0.3313 | Val Accuracy: 98.22%
# Rank 0 | Epoch 375/1000 | Train Loss: D=0.4570, G=0.8117 | Train Accuracy: 95.91% | Val Loss: D=0.3402 | Val Accuracy: 98.21%
# Rank 0 | Epoch 376/1000 | Train Loss: D=0.4421, G=0.8549 | Train Accuracy: 96.02% | Val Loss: D=0.3311 | Val Accuracy: 98.24%
# Rank 0 | Epoch 377/1000 | Train Loss: D=0.4392, G=0.8756 | Train Accuracy: 96.02% | Val Loss: D=0.3347 | Val Accuracy: 98.20%
# Rank 0 | Epoch 378/1000 | Train Loss: D=0.4484, G=0.9287 | Train Accuracy: 96.49% | Val Loss: D=0.3339 | Val Accuracy: 98.22%
# Rank 0 | Epoch 379/1000 | Train Loss: D=0.4423, G=0.8229 | Train Accuracy: 96.15% | Val Loss: D=0.3314 | Val Accuracy: 98.23%
# Rank 0 | Epoch 380/1000 | Train Loss: D=0.4293, G=0.8538 | Train Accuracy: 96.05% | Val Loss: D=0.3425 | Val Accuracy: 98.18%
# Rank 0 | Epoch 381/1000 | Train Loss: D=0.4066, G=0.9517 | Train Accuracy: 96.69% | Val Loss: D=0.3519 | Val Accuracy: 98.20%
# ...
# Rank 0 | Epoch 887/1000 | Train Loss: D=0.4427, G=1.0697 | Train Accuracy: 96.22% | Val Loss: D=0.3321 | Val Accuracy: 98.24%
# Rank 0 | Epoch 888/1000 | Train Loss: D=0.4403, G=1.0059 | Train Accuracy: 96.50% | Val Loss: D=0.3310 | Val Accuracy: 98.23%
# Rank 0 | Epoch 889/1000 | Train Loss: D=0.4568, G=1.0289 | Train Accuracy: 96.04% | Val Loss: D=0.3324 | Val Accuracy: 98.23%
# Rank 0 | Epoch 890/1000 | Train Loss: D=0.4516, G=0.8634 | Train Accuracy: 96.25% | Val Loss: D=0.3757 | Val Accuracy: 98.21%
# Rank 0 | Epoch 891/1000 | Train Loss: D=0.4386, G=1.0164 | Train Accuracy: 96.35% | Val Loss: D=0.3463 | Val Accuracy: 98.21%
# Rank 0 | Epoch 892/1000 | Train Loss: D=0.4649, G=1.0863 | Train Accuracy: 96.28% | Val Loss: D=0.3310 | Val Accuracy: 98.23%
# Rank 0 | Epoch 893/1000 | Train Loss: D=0.4341, G=0.9728 | Train Accuracy: 96.48% | Val Loss: D=0.3392 | Val Accuracy: 98.21%
# Rank 0 | Epoch 894/1000 | Train Loss: D=0.4399, G=1.1777 | Train Accuracy: 96.50% | Val Loss: D=0.3315 | Val Accuracy: 98.21%
# Rank 0 | Epoch 895/1000 | Train Loss: D=0.4328, G=1.1106 | Train Accuracy: 96.79% | Val Loss: D=0.3442 | Val Accuracy: 98.22%
# Rank 0 | Epoch 896/1000 | Train Loss: D=0.4321, G=1.0634 | Train Accuracy: 96.72% | Val Loss: D=0.3310 | Val Accuracy: 98.23%
# Rank 0 | Epoch 897/1000 | Train Loss: D=0.4462, G=1.0264 | Train Accuracy: 96.31% | Val Loss: D=0.3310 | Val Accuracy: 98.23%
# Rank 0 | Epoch 898/1000 | Train Loss: D=0.4361, G=1.0301 | Train Accuracy: 96.24% | Val Loss: D=0.3310 | Val Accuracy: 98.23%
# Rank 0 | Epoch 899/1000 | Train Loss: D=0.4337, G=1.0428 | Train Accuracy: 96.78% | Val Loss: D=0.3561 | Val Accuracy: 98.19%
# Rank 0 | Epoch 900/1000 | Train Loss: D=0.4308, G=0.9960 | Train Accuracy: 96.63% | Val Loss: D=0.3528 | Val Accuracy: 98.20%
# Rank 0 | Epoch 901/1000 | Train Loss: D=0.4401, G=1.0141 | Train Accuracy: 96.14% | Val Loss: D=0.3560 | Val Accuracy: 98.19%
# Rank 0 | Epoch 902/1000 | Train Loss: D=0.4450, G=0.9840 | Train Accuracy: 96.41% | Val Loss: D=0.3604 | Val Accuracy: 98.20%
# Rank 0 | Epoch 903/1000 | Train Loss: D=0.4454, G=1.0907 | Train Accuracy: 96.49% | Val Loss: D=0.3831 | Val Accuracy: 98.21%
# Rank 0 | Epoch 904/1000 | Train Loss: D=0.4278, G=1.1591 | Train Accuracy: 96.74% | Val Loss: D=0.3397 | Val Accuracy: 98.22%
# Rank 0 | Epoch 905/1000 | Train Loss: D=0.4384, G=1.0468 | Train Accuracy: 96.65% | Val Loss: D=0.3680 | Val Accuracy: 98.16%
# Rank 0 | Epoch 906/1000 | Train Loss: D=0.4430, G=0.9760 | Train Accuracy: 96.23% | Val Loss: D=0.3600 | Val Accuracy: 98.20%
# Rank 0 | Epoch 907/1000 | Train Loss: D=0.4520, G=0.9794 | Train Accuracy: 96.02% | Val Loss: D=0.3395 | Val Accuracy: 98.22%
# Rank 0 | Epoch 908/1000 | Train Loss: D=0.4308, G=1.0035 | Train Accuracy: 96.45% | Val Loss: D=0.3311 | Val Accuracy: 98.22%
# Rank 0 | Epoch 909/1000 | Train Loss: D=0.4605, G=0.9530 | Train Accuracy: 95.78% | Val Loss: D=0.3437 | Val Accuracy: 98.20%
# Rank 0 | Epoch 910/1000 | Train Loss: D=0.4376, G=0.9690 | Train Accuracy: 96.70% | Val Loss: D=0.3316 | Val Accuracy: 98.22%
# Rank 0 | Epoch 911/1000 | Train Loss: D=0.4471, G=1.0386 | Train Accuracy: 96.30% | Val Loss: D=0.3901 | Val Accuracy: 98.12%
# Rank 0 | Epoch 912/1000 | Train Loss: D=0.4470, G=0.9406 | Train Accuracy: 96.12% | Val Loss: D=0.3362 | Val Accuracy: 98.19%
# Rank 0 | Epoch 913/1000 | Train Loss: D=0.4607, G=1.0394 | Train Accuracy: 96.30% | Val Loss: D=0.3401 | Val Accuracy: 98.17%
# Rank 0 | Epoch 914/1000 | Train Loss: D=0.4070, G=1.1329 | Train Accuracy: 97.04% | Val Loss: D=0.3317 | Val Accuracy: 98.23%
# Rank 0 | Epoch 915/1000 | Train Loss: D=0.4357, G=1.1924 | Train Accuracy: 96.58% | Val Loss: D=0.3312 | Val Accuracy: 98.21%
# Rank 0 | Epoch 916/1000 | Train Loss: D=0.4542, G=1.0738 | Train Accuracy: 96.38% | Val Loss: D=0.3377 | Val Accuracy: 98.17%
# Rank 0 | Epoch 917/1000 | Train Loss: D=0.4493, G=1.0407 | Train Accuracy: 96.09% | Val Loss: D=0.3421 | Val Accuracy: 98.19%
# Rank 0 | Epoch 918/1000 | Train Loss: D=0.4312, G=1.0174 | Train Accuracy: 96.50% | Val Loss: D=0.3616 | Val Accuracy: 98.17%
# Rank 0 | Epoch 919/1000 | Train Loss: D=0.4586, G=1.1011 | Train Accuracy: 96.14% | Val Loss: D=0.3310 | Val Accuracy: 98.23%
# Rank 0 | Epoch 920/1000 | Train Loss: D=0.4568, G=0.9780 | Train Accuracy: 96.06% | Val Loss: D=0.3317 | Val Accuracy: 98.16%
# Rank 0 | Epoch 921/1000 | Train Loss: D=0.4376, G=1.0876 | Train Accuracy: 96.23% | Val Loss: D=0.3311 | Val Accuracy: 98.22%
# Rank 0 | Epoch 922/1000 | Train Loss: D=0.4403, G=1.0583 | Train Accuracy: 96.71% | Val Loss: D=0.3314 | Val Accuracy: 98.21%
# Rank 0 | Epoch 923/1000 | Train Loss: D=0.4262, G=1.0882 | Train Accuracy: 96.78% | Val Loss: D=0.3334 | Val Accuracy: 98.14%
# Rank 0 | Epoch 924/1000 | Train Loss: D=0.4245, G=1.1151 | Train Accuracy: 96.64% | Val Loss: D=0.3421 | Val Accuracy: 98.18%
# Rank 0 | Epoch 925/1000 | Train Loss: D=0.4327, G=1.1155 | Train Accuracy: 96.22% | Val Loss: D=0.3315 | Val Accuracy: 98.21%
# Rank 0 | Epoch 926/1000 | Train Loss: D=0.4217, G=1.1644 | Train Accuracy: 96.86% | Val Loss: D=0.3342 | Val Accuracy: 98.20%
# Rank 0 | Epoch 927/1000 | Train Loss: D=0.4286, G=1.1531 | Train Accuracy: 96.66% | Val Loss: D=0.3356 | Val Accuracy: 98.23%
# Rank 0 | Epoch 928/1000 | Train Loss: D=0.4366, G=1.0525 | Train Accuracy: 96.54% | Val Loss: D=0.3340 | Val Accuracy: 98.22%
# Rank 0 | Epoch 929/1000 | Train Loss: D=0.4253, G=1.0694 | Train Accuracy: 97.03% | Val Loss: D=0.3342 | Val Accuracy: 98.21%
# Rank 0 | Epoch 930/1000 | Train Loss: D=0.4366, G=1.0107 | Train Accuracy: 96.41% | Val Loss: D=0.3376 | Val Accuracy: 98.19%
# Rank 0 | Epoch 931/1000 | Train Loss: D=0.4366, G=1.1032 | Train Accuracy: 96.63% | Val Loss: D=0.3447 | Val Accuracy: 98.16%
# Rank 0 | Epoch 932/1000 | Train Loss: D=0.4339, G=1.1099 | Train Accuracy: 96.54% | Val Loss: D=0.3345 | Val Accuracy: 98.18%
# Rank 0 | Epoch 933/1000 | Train Loss: D=0.4560, G=0.9893 | Train Accuracy: 96.14% | Val Loss: D=0.3310 | Val Accuracy: 98.23%
# Rank 0 | Epoch 934/1000 | Train Loss: D=0.4358, G=1.0787 | Train Accuracy: 96.45% | Val Loss: D=0.3419 | Val Accuracy: 98.19%
# Rank 0 | Epoch 935/1000 | Train Loss: D=0.4435, G=1.0156 | Train Accuracy: 96.27% | Val Loss: D=0.3524 | Val Accuracy: 98.18%
# Rank 0 | Epoch 936/1000 | Train Loss: D=0.4423, G=0.9966 | Train Accuracy: 96.28% | Val Loss: D=0.3420 | Val Accuracy: 98.22%
# Rank 0 | Epoch 937/1000 | Train Loss: D=0.4242, G=1.1044 | Train Accuracy: 96.77% | Val Loss: D=0.3439 | Val Accuracy: 98.19%
# Rank 0 | Epoch 938/1000 | Train Loss: D=0.4493, G=0.9382 | Train Accuracy: 96.22% | Val Loss: D=0.3708 | Val Accuracy: 98.20%
# Rank 0 | Epoch 939/1000 | Train Loss: D=0.4408, G=0.9544 | Train Accuracy: 96.55% | Val Loss: D=0.3429 | Val Accuracy: 98.08%
# Rank 0 | Epoch 940/1000 | Train Loss: D=0.4437, G=0.9309 | Train Accuracy: 96.25% | Val Loss: D=0.3458 | Val Accuracy: 98.21%
# Rank 0 | Epoch 941/1000 | Train Loss: D=0.4416, G=0.9954 | Train Accuracy: 96.05% | Val Loss: D=0.3310 | Val Accuracy: 98.23%
# Rank 0 | Epoch 942/1000 | Train Loss: D=0.4494, G=0.9078 | Train Accuracy: 95.80% | Val Loss: D=0.3313 | Val Accuracy: 98.22%
# Rank 0 | Epoch 943/1000 | Train Loss: D=0.4436, G=0.9560 | Train Accuracy: 96.18% | Val Loss: D=0.3309 | Val Accuracy: 98.24%
# Rank 0 | Epoch 944/1000 | Train Loss: D=0.4371, G=1.0535 | Train Accuracy: 96.48% | Val Loss: D=0.3423 | Val Accuracy: 98.16%
# Rank 0 | Epoch 945/1000 | Train Loss: D=0.3996, G=1.0915 | Train Accuracy: 97.18% | Val Loss: D=0.3318 | Val Accuracy: 98.22%
# Rank 0 | Epoch 946/1000 | Train Loss: D=0.4356, G=1.0425 | Train Accuracy: 96.39% | Val Loss: D=0.3435 | Val Accuracy: 98.20%
# Rank 0 | Epoch 947/1000 | Train Loss: D=0.4286, G=1.0335 | Train Accuracy: 96.30% | Val Loss: D=0.3414 | Val Accuracy: 98.24%
# Rank 0 | Epoch 948/1000 | Train Loss: D=0.4188, G=1.0781 | Train Accuracy: 96.78% | Val Loss: D=0.3311 | Val Accuracy: 98.24%
# Rank 0 | Epoch 949/1000 | Train Loss: D=0.4462, G=1.0066 | Train Accuracy: 96.34% | Val Loss: D=0.3336 | Val Accuracy: 98.23%
# Rank 0 | Epoch 950/1000 | Train Loss: D=0.4141, G=1.2407 | Train Accuracy: 97.09% | Val Loss: D=0.3402 | Val Accuracy: 98.22%
# Rank 0 | Epoch 951/1000 | Train Loss: D=0.4539, G=0.9688 | Train Accuracy: 96.07% | Val Loss: D=0.3394 | Val Accuracy: 98.22%
# Rank 0 | Epoch 952/1000 | Train Loss: D=0.4658, G=0.9959 | Train Accuracy: 96.16% | Val Loss: D=0.3318 | Val Accuracy: 98.22%
# Rank 0 | Epoch 953/1000 | Train Loss: D=0.4255, G=0.9398 | Train Accuracy: 96.54% | Val Loss: D=0.3756 | Val Accuracy: 98.20%
# Rank 0 | Epoch 954/1000 | Train Loss: D=0.4284, G=1.0302 | Train Accuracy: 96.60% | Val Loss: D=0.3350 | Val Accuracy: 98.16%
# Rank 0 | Epoch 955/1000 | Train Loss: D=0.4580, G=1.0607 | Train Accuracy: 96.38% | Val Loss: D=0.3377 | Val Accuracy: 98.20%
# Rank 0 | Epoch 956/1000 | Train Loss: D=0.4338, G=0.9425 | Train Accuracy: 96.64% | Val Loss: D=0.3404 | Val Accuracy: 98.21%
# Rank 0 | Epoch 957/1000 | Train Loss: D=0.4737, G=0.8432 | Train Accuracy: 96.01% | Val Loss: D=0.3372 | Val Accuracy: 98.20%
# Rank 0 | Epoch 958/1000 | Train Loss: D=0.4467, G=0.8486 | Train Accuracy: 96.31% | Val Loss: D=0.3327 | Val Accuracy: 98.22%
# Rank 0 | Epoch 959/1000 | Train Loss: D=0.4335, G=0.9352 | Train Accuracy: 96.37% | Val Loss: D=0.3993 | Val Accuracy: 98.17%
# Rank 0 | Epoch 960/1000 | Train Loss: D=0.4401, G=1.0062 | Train Accuracy: 96.13% | Val Loss: D=0.3372 | Val Accuracy: 98.21%
# Rank 0 | Epoch 961/1000 | Train Loss: D=0.4215, G=1.0601 | Train Accuracy: 96.81% | Val Loss: D=0.3601 | Val Accuracy: 98.19%
# Rank 0 | Epoch 962/1000 | Train Loss: D=0.4394, G=1.0696 | Train Accuracy: 96.39% | Val Loss: D=0.3332 | Val Accuracy: 98.22%
# Rank 0 | Epoch 963/1000 | Train Loss: D=0.4405, G=1.0125 | Train Accuracy: 96.54% | Val Loss: D=0.3432 | Val Accuracy: 98.19%
# Rank 0 | Epoch 964/1000 | Train Loss: D=0.4599, G=0.9514 | Train Accuracy: 96.07% | Val Loss: D=0.3366 | Val Accuracy: 98.20%
# Rank 0 | Epoch 965/1000 | Train Loss: D=0.4104, G=1.4525 | Train Accuracy: 97.33% | Val Loss: D=0.3448 | Val Accuracy: 98.22%
# Rank 0 | Epoch 966/1000 | Train Loss: D=0.4565, G=0.8615 | Train Accuracy: 96.25% | Val Loss: D=0.3335 | Val Accuracy: 98.22%
# Rank 0 | Epoch 967/1000 | Train Loss: D=0.4467, G=0.8424 | Train Accuracy: 95.88% | Val Loss: D=0.3315 | Val Accuracy: 98.19%
# Rank 0 | Epoch 968/1000 | Train Loss: D=0.4290, G=0.8997 | Train Accuracy: 96.18% | Val Loss: D=0.3533 | Val Accuracy: 98.19%
# Rank 0 | Epoch 969/1000 | Train Loss: D=0.4218, G=1.0478 | Train Accuracy: 96.50% | Val Loss: D=0.3618 | Val Accuracy: 98.21%
# Rank 0 | Epoch 970/1000 | Train Loss: D=0.4365, G=0.9367 | Train Accuracy: 96.04% | Val Loss: D=0.3483 | Val Accuracy: 98.22%
# Rank 0 | Epoch 971/1000 | Train Loss: D=0.4203, G=1.0403 | Train Accuracy: 96.32% | Val Loss: D=0.3459 | Val Accuracy: 98.19%
# Rank 0 | Epoch 972/1000 | Train Loss: D=0.4118, G=1.0399 | Train Accuracy: 96.99% | Val Loss: D=0.3323 | Val Accuracy: 98.21%
# Rank 0 | Epoch 973/1000 | Train Loss: D=0.4360, G=1.0700 | Train Accuracy: 96.57% | Val Loss: D=0.3355 | Val Accuracy: 98.19%
# Rank 0 | Epoch 974/1000 | Train Loss: D=0.4081, G=1.0611 | Train Accuracy: 97.06% | Val Loss: D=0.3338 | Val Accuracy: 98.18%
# Rank 0 | Epoch 975/1000 | Train Loss: D=0.4569, G=0.9768 | Train Accuracy: 96.19% | Val Loss: D=0.3318 | Val Accuracy: 98.21%
# Rank 0 | Epoch 976/1000 | Train Loss: D=0.4474, G=0.8848 | Train Accuracy: 95.81% | Val Loss: D=0.3328 | Val Accuracy: 98.18%
# Rank 0 | Epoch 977/1000 | Train Loss: D=0.4291, G=0.9165 | Train Accuracy: 96.31% | Val Loss: D=0.3311 | Val Accuracy: 98.22%
# Rank 0 | Epoch 978/1000 | Train Loss: D=0.4355, G=0.9813 | Train Accuracy: 96.31% | Val Loss: D=0.3311 | Val Accuracy: 98.22%
# Rank 0 | Epoch 979/1000 | Train Loss: D=0.4538, G=0.8771 | Train Accuracy: 95.98% | Val Loss: D=0.3311 | Val Accuracy: 98.22%
# Rank 0 | Epoch 980/1000 | Train Loss: D=0.4365, G=0.8791 | Train Accuracy: 96.19% | Val Loss: D=0.3372 | Val Accuracy: 98.19%
# Rank 0 | Epoch 981/1000 | Train Loss: D=0.4185, G=1.0287 | Train Accuracy: 96.74% | Val Loss: D=0.3357 | Val Accuracy: 98.19%
# Rank 0 | Epoch 982/1000 | Train Loss: D=0.4396, G=0.9705 | Train Accuracy: 96.35% | Val Loss: D=0.4262 | Val Accuracy: 98.16%
# Rank 0 | Epoch 983/1000 | Train Loss: D=0.4325, G=1.0951 | Train Accuracy: 96.74% | Val Loss: D=0.3330 | Val Accuracy: 98.18%
# Rank 0 | Epoch 984/1000 | Train Loss: D=0.4163, G=1.1799 | Train Accuracy: 96.90% | Val Loss: D=0.3309 | Val Accuracy: 98.24%
# Rank 0 | Epoch 985/1000 | Train Loss: D=0.4576, G=1.0142 | Train Accuracy: 95.96% | Val Loss: D=0.3324 | Val Accuracy: 98.23%
# Rank 0 | Epoch 986/1000 | Train Loss: D=0.4516, G=1.0213 | Train Accuracy: 96.39% | Val Loss: D=0.3344 | Val Accuracy: 98.21%
# Rank 0 | Epoch 987/1000 | Train Loss: D=0.4306, G=1.0458 | Train Accuracy: 96.57% | Val Loss: D=0.3337 | Val Accuracy: 98.22%
# Rank 0 | Epoch 988/1000 | Train Loss: D=0.4109, G=1.0868 | Train Accuracy: 96.85% | Val Loss: D=0.3388 | Val Accuracy: 98.22%
# Rank 0 | Epoch 989/1000 | Train Loss: D=0.4283, G=1.1614 | Train Accuracy: 96.74% | Val Loss: D=0.3319 | Val Accuracy: 98.20%
# Rank 0 | Epoch 990/1000 | Train Loss: D=0.4304, G=1.2440 | Train Accuracy: 96.78% | Val Loss: D=0.3313 | Val Accuracy: 98.23%
# Rank 0 | Epoch 991/1000 | Train Loss: D=0.4369, G=1.1252 | Train Accuracy: 96.67% | Val Loss: D=0.3362 | Val Accuracy: 98.19%
# Rank 0 | Epoch 992/1000 | Train Loss: D=0.4148, G=1.1374 | Train Accuracy: 96.90% | Val Loss: D=0.3435 | Val Accuracy: 98.23%
# Rank 0 | Epoch 993/1000 | Train Loss: D=0.4263, G=1.1518 | Train Accuracy: 96.74% | Val Loss: D=0.3316 | Val Accuracy: 98.22%
# Rank 0 | Epoch 994/1000 | Train Loss: D=0.4411, G=1.0631 | Train Accuracy: 96.31% | Val Loss: D=0.3344 | Val Accuracy: 98.22%
# Rank 0 | Epoch 995/1000 | Train Loss: D=0.4203, G=1.0509 | Train Accuracy: 96.72% | Val Loss: D=0.3309 | Val Accuracy: 98.24%
# Rank 0 | Epoch 996/1000 | Train Loss: D=0.4340, G=1.0020 | Train Accuracy: 96.42% | Val Loss: D=0.3420 | Val Accuracy: 98.22%
# Rank 0 | Epoch 997/1000 | Train Loss: D=0.4348, G=1.0125 | Train Accuracy: 96.39% | Val Loss: D=0.3439 | Val Accuracy: 98.21%
# Rank 0 | Epoch 998/1000 | Train Loss: D=0.4139, G=1.0215 | Train Accuracy: 96.86% | Val Loss: D=0.3330 | Val Accuracy: 98.23%
# Rank 0 | Epoch 999/1000 | Train Loss: D=0.4425, G=0.9987 | Train Accuracy: 96.34% | Val Loss: D=0.3312 | Val Accuracy: 98.22%
# Rank 0 | Epoch 1000/1000 | Train Loss: D=0.4288, G=1.1854 | Train Accuracy: 96.61% | Val Loss: D=0.3309 | Val Accuracy: 98.24%
# Training Complete
# Final dataset with synthetic data saved as CombinedDataset_with_SyntheticData.csv
# Inside Test
# /home/amd/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 if __name__ == "__main__":
# ----> 2     main_worker(rank=0, world_size=1, data_path='CompletedDataset.xlsx')
#
# Cell In[19], line 81, in main_worker(rank, world_size, data_path)
#      75 print("Final dataset with synthetic data saved as CombinedDataset_with_SyntheticData.csv")
#      80 # Test the model
# ---> 81 acgan.test(X_test, y_test, batch_size=64, rank=rank)
#      82 print("Testing Complete")
#
# Cell In[17], line 191, in ACGAN.test(self, X_test, y_test, batch_size, rank)
#     188 recall = recall_score(all_labels, all_predictions, pos_label=1)
#     189 f1 = f1_score(all_labels, all_predictions, pos_label=1)
# --> 191 log_to_file(f"Rank {rank} | Epoch {epoch+1}/{epochs} | "
#     192             f"Train Loss: D={train_d_loss:.4f}, G={train_g_loss:.4f} | "
#     193             f"Train Accuracy: {train_accuracy:.2f}% | "
#     194             f"Val Loss: D={val_d_loss:.4f} | Val Accuracy: {val_accuracy:.2f}%")
#
# NameError: name 'epoch' is not defined
